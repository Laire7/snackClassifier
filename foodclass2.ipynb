# %%
import os
dataPath = os.path.join(os.getcwd(), 'data', 'snack')
dataPath
# Out:
# 'C:\\Users\\SBA\\pytorch\\pytorchEx\\data\\snack'

# %%
import random
snackType = os.listdir(dataPath)
print(snackType)
snackFiles = os.listdir(os.path.join(dataPath, snackType[0]))
print(snackFiles)
num = random.randint(0,len(snackType[0]))
print(snackFiles[0])
# Out:
# ['banana', 'blueberry', 'choco', 'cone', 'gum', 'octopus', 'shrimp']
# ['10095_0_m_1.jpg', '10095_0_m_11.jpg', '10095_0_m_14.jpg', '10095_0_m_15.jpg', '10095_0_m_17.jpg', '10095_0_m_19.jpg', '10095_0_m_2.jpg', '10095_0_m_20.jpg', '10095_0_m_23.jpg', '10095_0_m_24.jpg', '10095_0_m_3.jpg', '10095_0_m_4.jpg', '10095_0_m_5.jpg', '10095_0_m_6.jpg', '10095_0_m_7.jpg', '10095_0_m_8.jpg', '10095_0_m_9.jpg', '10095_0_s_11.jpg', '10095_0_s_12.jpg', '10095_0_s_13.jpg', '10095_0_s_14.jpg', '10095_0_s_15.jpg', '10095_0_s_16.jpg', '10095_0_s_17.jpg', '10095_0_s_19.jpg', '10095_0_s_2.jpg', '10095_0_s_20.jpg', '10095_0_s_21.jpg', '10095_0_s_23.jpg', '10095_0_s_3.jpg', '10095_0_s_5.jpg', '10095_0_s_6.jpg', '10095_0_s_7.jpg', '10095_0_s_8.jpg', '10095_0_s_9.jpg', '10095_30_m_1.jpg', '10095_30_m_11.jpg', '10095_30_m_12.jpg', '10095_30_m_13.jpg', '10095_30_m_14.jpg', '10095_30_m_16.jpg', '10095_30_m_17.jpg', '10095_30_m_18.jpg', '10095_30_m_19.jpg', '10095_30_m_2.jpg', '10095_30_m_20.jpg', '10095_30_m_22.jpg', '10095_30_m_23.jpg', '10095_30_m_24.jpg', '10095_30_m_4.jpg', '10095_30_m_5.jpg', '10095_30_m_7.jpg', '10095_30_m_8.jpg', '10095_30_m_9.jpg', '10095_30_s_1.jpg', '10095_30_s_10.jpg', '10095_30_s_11.jpg', '10095_30_s_12.jpg', '10095_30_s_14.jpg', '10095_30_s_15.jpg', '10095_30_s_16.jpg', '10095_30_s_17.jpg', '10095_30_s_18.jpg', '10095_30_s_2.jpg', '10095_30_s_20.jpg', '10095_30_s_21.jpg', '10095_30_s_22.jpg', '10095_30_s_23.jpg', '10095_30_s_24.jpg', '10095_30_s_3.jpg', '10095_30_s_5.jpg', '10095_30_s_7.jpg', '10095_30_s_8.jpg', '10095_30_s_9.jpg', '10095_60_m_1.jpg', '10095_60_m_11.jpg', '10095_60_m_12.jpg', '10095_60_m_13.jpg', '10095_60_m_15.jpg', '10095_60_m_16.jpg', '10095_60_m_17.jpg', '10095_60_m_18.jpg', '10095_60_m_19.jpg', '10095_60_m_2.jpg', '10095_60_m_20.jpg', '10095_60_m_21.jpg', '10095_60_m_22.jpg', '10095_60_m_23.jpg', '10095_60_m_3.jpg', '10095_60_m_4.jpg', '10095_60_m_5.jpg', '10095_60_m_6.jpg', '10095_60_m_8.jpg', '10095_60_m_9.jpg', '10095_60_s_1.jpg', '10095_60_s_10.jpg', '10095_60_s_12.jpg', '10095_60_s_14.jpg', '10095_60_s_15.jpg', '10095_60_s_17.jpg', '10095_60_s_18.jpg', '10095_60_s_19.jpg', '10095_60_s_2.jpg', '10095_60_s_20.jpg', '10095_60_s_22.jpg', '10095_60_s_23.jpg', '10095_60_s_24.jpg', '10095_60_s_3.jpg', '10095_60_s_4.jpg', '10095_60_s_5.jpg', '10095_60_s_6.jpg', '10095_60_s_7.jpg', '10095_60_s_8.jpg', '10095_60_s_9.jpg']
# 10095_0_m_1.jpg

# %%
trainRatio = 0.6
validRatio = 0.2
testRatio = 1 - trainRatio - validRatio

# %%
import shutil

for snack in snackType:
    snackPath = os.path.join(dataPath, snack)
    files = os.listdir(snackPath)
    
    trainCount = int(trainRatio * len(files))
    validCount = int(validRatio * len(files))
    testCount = len(files) - trainCount - validCount
    print(f'trainCount:{trainCount} validCount:{validCount} testCount:{testCount}')

    print(f'files {len(files)}')
    shuffleFiles = random.sample(files, len(files))
    print(f'shuffleFiles {len(shuffleFiles)}')

    # shutil.rmtree(os.path.join(snackPath,'train'))
    # shutil.rmtree(os.path.join(snackPath,'valid'))
    # shutil.rmtree(os.path.join(snackPath,'test'))
    
    # os.makedirs(os.path.join(snackPath,'train'), exist_ok=True)
    # os.makedirs(os.path.join(snackPath,'valid'), exist_ok=True)
    # os.makedirs(os.path.join(snackPath,'test'), exist_ok=True)
    
    train_data = shuffleFiles[:trainCount-1]
    valid_data = shuffleFiles[trainCount: trainCount + validCount-1]
    test_data = shuffleFiles[trainCount + validCount:]
    print(f'Data: train {len(train_data)}, valid {len(valid_data)}, test{len(test_data)}')
# Out:
# trainCount:68 validCount:22 testCount:24
# files 114
# shuffleFiles 114
# Data: train 67, valid 21, test24
# trainCount:68 validCount:22 testCount:24
# files 114
# shuffleFiles 114
# Data: train 67, valid 21, test24
# trainCount:68 validCount:22 testCount:24
# files 114
# shuffleFiles 114
# Data: train 67, valid 21, test24
# trainCount:68 validCount:22 testCount:24
# files 114
# shuffleFiles 114
# Data: train 67, valid 21, test24
# trainCount:68 validCount:22 testCount:24
# files 114
# shuffleFiles 114
# Data: train 67, valid 21, test24
# trainCount:68 validCount:22 testCount:24
# files 114
# shuffleFiles 114
# Data: train 67, valid 21, test24
# trainCount:68 validCount:22 testCount:24
# files 114
# shuffleFiles 114
# Data: train 67, valid 21, test24

# %%
trainFiles = train_data
validFiles = valid_data
testFiles = test_data
print(len(trainFiles))
print(len(validFiles))
print(len(testFiles))
# Out:
# 67
# 21
# 24

# %%
# small데이터셋을 위한 폴더를 지정하고 4000장을 나눠서 보관
import os

sdata = 'sdata\snack'
train_sdata = os.path.join(sdata,'train')
valid_sdata = os.path.join(sdata,'valid')
test_sdata = os.path.join(sdata,'test')

trainValidTestList = ['train', 'valid','test']
for trainValidTest in trainValidTestList:
    if os.path.exists(os.path.join(sdata, trainValidTest)):
        shutil.rmtree(os.path.join(sdata, trainValidTest))

os.makedirs(train_sdata, exist_ok=True)
os.makedirs(valid_sdata, exist_ok=True)
os.makedirs(test_sdata, exist_ok=True)

train_sdata_banana = os.path.join(train_sdata,'banana')
train_sdata_blueberry = os.path.join(train_sdata,'blueberry')
train_sdata_choco = os.path.join(train_sdata,'choco')
train_sdata_cone = os.path.join(train_sdata,'cone')
train_sdata_gum = os.path.join(train_sdata,'gum')
train_sdata_octopus = os.path.join(train_sdata,'octopus')
train_sdata_shrimp = os.path.join(train_sdata,'shrimp')
os.makedirs(train_sdata_banana, exist_ok=True)
os.makedirs(train_sdata_blueberry, exist_ok=True)
os.makedirs(train_sdata_choco, exist_ok=True)
os.makedirs(train_sdata_cone, exist_ok=True)
os.makedirs(train_sdata_gum, exist_ok=True)
os.makedirs(train_sdata_octopus, exist_ok=True)
os.makedirs(train_sdata_shrimp, exist_ok=True)

valid_sdata_banana = os.path.join(valid_sdata,'banana')
valid_sdata_blueberry = os.path.join(valid_sdata,'blueberry')
valid_sdata_choco = os.path.join(valid_sdata,'choco')
valid_sdata_cone = os.path.join(valid_sdata,'cone')
valid_sdata_gum = os.path.join(valid_sdata,'gum')
valid_sdata_octopus = os.path.join(valid_sdata,'octopus')
valid_sdata_shrimp = os.path.join(valid_sdata,'shrimp')
os.makedirs(valid_sdata_banana, exist_ok=True)
os.makedirs(valid_sdata_blueberry, exist_ok=True)
os.makedirs(valid_sdata_choco, exist_ok=True)
os.makedirs(valid_sdata_cone, exist_ok=True)
os.makedirs(valid_sdata_gum, exist_ok=True)
os.makedirs(valid_sdata_octopus, exist_ok=True)
os.makedirs(valid_sdata_shrimp, exist_ok=True)

test_sdata_banana = os.path.join(test_sdata,'banana')
test_sdata_blueberry = os.path.join(test_sdata,'blueberry')
test_sdata_choco = os.path.join(test_sdata,'choco')
test_sdata_cone = os.path.join(test_sdata,'cone')
test_sdata_gum = os.path.join(test_sdata,'gum')
test_sdata_octopus = os.path.join(test_sdata,'octopus')
test_sdata_shrimp = os.path.join(test_sdata,'shrimp')
os.makedirs(test_sdata_banana, exist_ok=True)
os.makedirs(test_sdata_blueberry, exist_ok=True)
os.makedirs(test_sdata_choco, exist_ok=True)
os.makedirs(test_sdata_cone, exist_ok=True)
os.makedirs(test_sdata_gum, exist_ok=True)
os.makedirs(test_sdata_octopus, exist_ok=True)
os.makedirs(test_sdata_shrimp, exist_ok=True)

# %%
# 한 클래스의 이미지 갯수 * 2
train_num = len(train_data)
valid_num = len(valid_data)
test_num  = len(test_data)

train_range = [0, train_num-1]
valid_range = [train_num, train_num + valid_num -1]
test_range  = [train_num + valid_num, train_num + valid_num + test_num-1]

print(train_range)
print(valid_range)
print(test_range)
# Out:
# [0, 66]
# [67, 87]
# [88, 111]

# %%
import os
import shutil

# 데이터셋 디렉토리 경로 설정 (데이터셋이 저장된 경로로 수정하세요)
dataset_dir = 'data\snack'

# 새로운 train, valid, test 디렉토리 생성 경로
base_dir = 'sdata\snack'

# 클래스 목록
classes = ['banana', 'blueberry', 'choco', 'cone', 'gum', 'octopus', 'shrimp']

# 폴더 경로 생성
train_dir = os.path.join(base_dir, 'train')
valid_dir = os.path.join(base_dir, 'valid')
test_dir = os.path.join(base_dir, 'test')

# 폴더 생성 함수
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

# train, valid, test 폴더 및 각각의 클래스 폴더 생성
for cls in classes:
    create_dir(os.path.join(train_dir, cls))
    create_dir(os.path.join(valid_dir, cls))

# 이미지 복사 함수
def copy_images(start_idx, end_idx, src_dir, dst_dir, label):
    srcFiles = os.listdir(src_dir)
    for i in range(start_idx, end_idx + 1):
        file_name = f'{label}.{i}.jpg'
        # print(f' fileName {file_name}')
        src_path = os.path.join(src_dir, srcFiles[i])
        print(f'src {src_path}')
        dst_path = os.path.join(dst_dir, file_name)
        print(f'dst {dst_path}')
        if os.path.exists(src_path):
            shutil.copy(src_path, dst_path)

# 클래스별로 train, valid, test 데이터셋 구성
for cls in classes:
    # train dataset 구성 (0~999)
    copy_images(train_range[0], train_range[1], os.path.join(dataset_dir, cls), os.path.join(train_dir, cls), cls)
    # print(train_range[0], train_range[1], dataset_dir, os.path.join(train_dir, cls))

    # valid dataset 구성 (1000~1249)
    copy_images(valid_range[0], valid_range[1], os.path.join(dataset_dir, cls), os.path.join(valid_dir, cls), cls)

    # test dataset 구성 (1250~1499)
    copy_images(test_range[0], test_range[1], os.path.join(dataset_dir, cls), os.path.join(test_dir, cls), cls)

print("데이터셋 분할 및 복사가 완료되었습니다.")
# Out:
# src data\snack\banana\10095_0_m_1.jpg
# dst sdata\snack\train\banana\banana.0.jpg
# src data\snack\banana\10095_0_m_11.jpg
# dst sdata\snack\train\banana\banana.1.jpg
# src data\snack\banana\10095_0_m_14.jpg
# dst sdata\snack\train\banana\banana.2.jpg
# src data\snack\banana\10095_0_m_15.jpg
# dst sdata\snack\train\banana\banana.3.jpg
# src data\snack\banana\10095_0_m_17.jpg
# dst sdata\snack\train\banana\banana.4.jpg
# src data\snack\banana\10095_0_m_19.jpg
# dst sdata\snack\train\banana\banana.5.jpg
# src data\snack\banana\10095_0_m_2.jpg
# dst sdata\snack\train\banana\banana.6.jpg
# src data\snack\banana\10095_0_m_20.jpg
# dst sdata\snack\train\banana\banana.7.jpg
# src data\snack\banana\10095_0_m_23.jpg
# dst sdata\snack\train\banana\banana.8.jpg
# src data\snack\banana\10095_0_m_24.jpg
# dst sdata\snack\train\banana\banana.9.jpg
# src data\snack\banana\10095_0_m_3.jpg
# dst sdata\snack\train\banana\banana.10.jpg
# src data\snack\banana\10095_0_m_4.jpg
# dst sdata\snack\train\banana\banana.11.jpg
# src data\snack\banana\10095_0_m_5.jpg
# dst sdata\snack\train\banana\banana.12.jpg
# src data\snack\banana\10095_0_m_6.jpg
# dst sdata\snack\train\banana\banana.13.jpg
# src data\snack\banana\10095_0_m_7.jpg
# dst sdata\snack\train\banana\banana.14.jpg
# src data\snack\banana\10095_0_m_8.jpg
# dst sdata\snack\train\banana\banana.15.jpg
# src data\snack\banana\10095_0_m_9.jpg
# dst sdata\snack\train\banana\banana.16.jpg
# src data\snack\banana\10095_0_s_11.jpg
# dst sdata\snack\train\banana\banana.17.jpg
# src data\snack\banana\10095_0_s_12.jpg
# dst sdata\snack\train\banana\banana.18.jpg
# src data\snack\banana\10095_0_s_13.jpg
# dst sdata\snack\train\banana\banana.19.jpg
# src data\snack\banana\10095_0_s_14.jpg
# dst sdata\snack\train\banana\banana.20.jpg
# src data\snack\banana\10095_0_s_15.jpg
# dst sdata\snack\train\banana\banana.21.jpg
# src data\snack\banana\10095_0_s_16.jpg
# dst sdata\snack\train\banana\banana.22.jpg
# src data\snack\banana\10095_0_s_17.jpg
# dst sdata\snack\train\banana\banana.23.jpg
# src data\snack\banana\10095_0_s_19.jpg
# dst sdata\snack\train\banana\banana.24.jpg
# src data\snack\banana\10095_0_s_2.jpg
# dst sdata\snack\train\banana\banana.25.jpg
# src data\snack\banana\10095_0_s_20.jpg
# dst sdata\snack\train\banana\banana.26.jpg
# src data\snack\banana\10095_0_s_21.jpg
# dst sdata\snack\train\banana\banana.27.jpg
# src data\snack\banana\10095_0_s_23.jpg
# dst sdata\snack\train\banana\banana.28.jpg
# src data\snack\banana\10095_0_s_3.jpg
# dst sdata\snack\train\banana\banana.29.jpg
# src data\snack\banana\10095_0_s_5.jpg
# dst sdata\snack\train\banana\banana.30.jpg
# src data\snack\banana\10095_0_s_6.jpg
# dst sdata\snack\train\banana\banana.31.jpg
# src data\snack\banana\10095_0_s_7.jpg
# dst sdata\snack\train\banana\banana.32.jpg
# src data\snack\banana\10095_0_s_8.jpg
# dst sdata\snack\train\banana\banana.33.jpg
# src data\snack\banana\10095_0_s_9.jpg
# dst sdata\snack\train\banana\banana.34.jpg
# src data\snack\banana\10095_30_m_1.jpg
# dst sdata\snack\train\banana\banana.35.jpg
# src data\snack\banana\10095_30_m_11.jpg
# dst sdata\snack\train\banana\banana.36.jpg
# src data\snack\banana\10095_30_m_12.jpg
# dst sdata\snack\train\banana\banana.37.jpg
# src data\snack\banana\10095_30_m_13.jpg
# dst sdata\snack\train\banana\banana.38.jpg
# src data\snack\banana\10095_30_m_14.jpg
# dst sdata\snack\train\banana\banana.39.jpg
# src data\snack\banana\10095_30_m_16.jpg
# dst sdata\snack\train\banana\banana.40.jpg
# src data\snack\banana\10095_30_m_17.jpg
# dst sdata\snack\train\banana\banana.41.jpg
# src data\snack\banana\10095_30_m_18.jpg
# dst sdata\snack\train\banana\banana.42.jpg
# src data\snack\banana\10095_30_m_19.jpg
# dst sdata\snack\train\banana\banana.43.jpg
# src data\snack\banana\10095_30_m_2.jpg
# dst sdata\snack\train\banana\banana.44.jpg
# src data\snack\banana\10095_30_m_20.jpg
# dst sdata\snack\train\banana\banana.45.jpg
# src data\snack\banana\10095_30_m_22.jpg
# dst sdata\snack\train\banana\banana.46.jpg
# src data\snack\banana\10095_30_m_23.jpg
# dst sdata\snack\train\banana\banana.47.jpg
# src data\snack\banana\10095_30_m_24.jpg
# dst sdata\snack\train\banana\banana.48.jpg
# src data\snack\banana\10095_30_m_4.jpg
# dst sdata\snack\train\banana\banana.49.jpg
# src data\snack\banana\10095_30_m_5.jpg
# dst sdata\snack\train\banana\banana.50.jpg
# src data\snack\banana\10095_30_m_7.jpg
# dst sdata\snack\train\banana\banana.51.jpg
# src data\snack\banana\10095_30_m_8.jpg
# dst sdata\snack\train\banana\banana.52.jpg
# src data\snack\banana\10095_30_m_9.jpg
# dst sdata\snack\train\banana\banana.53.jpg
# src data\snack\banana\10095_30_s_1.jpg
# dst sdata\snack\train\banana\banana.54.jpg
# src data\snack\banana\10095_30_s_10.jpg
# dst sdata\snack\train\banana\banana.55.jpg
# src data\snack\banana\10095_30_s_11.jpg
# dst sdata\snack\train\banana\banana.56.jpg
# src data\snack\banana\10095_30_s_12.jpg
# dst sdata\snack\train\banana\banana.57.jpg
# src data\snack\banana\10095_30_s_14.jpg
# dst sdata\snack\train\banana\banana.58.jpg
# src data\snack\banana\10095_30_s_15.jpg
# dst sdata\snack\train\banana\banana.59.jpg
# src data\snack\banana\10095_30_s_16.jpg
# dst sdata\snack\train\banana\banana.60.jpg
# src data\snack\banana\10095_30_s_17.jpg
# dst sdata\snack\train\banana\banana.61.jpg
# src data\snack\banana\10095_30_s_18.jpg
# dst sdata\snack\train\banana\banana.62.jpg
# src data\snack\banana\10095_30_s_2.jpg
# dst sdata\snack\train\banana\banana.63.jpg
# src data\snack\banana\10095_30_s_20.jpg
# dst sdata\snack\train\banana\banana.64.jpg
# src data\snack\banana\10095_30_s_21.jpg
# dst sdata\snack\train\banana\banana.65.jpg
# src data\snack\banana\10095_30_s_22.jpg
# dst sdata\snack\train\banana\banana.66.jpg
# src data\snack\banana\10095_30_s_23.jpg
# dst sdata\snack\valid\banana\banana.67.jpg
# src data\snack\banana\10095_30_s_24.jpg
# dst sdata\snack\valid\banana\banana.68.jpg
# src data\snack\banana\10095_30_s_3.jpg
# dst sdata\snack\valid\banana\banana.69.jpg
# src data\snack\banana\10095_30_s_5.jpg
# dst sdata\snack\valid\banana\banana.70.jpg
# src data\snack\banana\10095_30_s_7.jpg
# dst sdata\snack\valid\banana\banana.71.jpg
# src data\snack\banana\10095_30_s_8.jpg
# dst sdata\snack\valid\banana\banana.72.jpg
# src data\snack\banana\10095_30_s_9.jpg
# dst sdata\snack\valid\banana\banana.73.jpg
# src data\snack\banana\10095_60_m_1.jpg
# dst sdata\snack\valid\banana\banana.74.jpg
# src data\snack\banana\10095_60_m_11.jpg
# dst sdata\snack\valid\banana\banana.75.jpg
# src data\snack\banana\10095_60_m_12.jpg
# dst sdata\snack\valid\banana\banana.76.jpg
# src data\snack\banana\10095_60_m_13.jpg
# dst sdata\snack\valid\banana\banana.77.jpg
# src data\snack\banana\10095_60_m_15.jpg
# dst sdata\snack\valid\banana\banana.78.jpg
# src data\snack\banana\10095_60_m_16.jpg
# dst sdata\snack\valid\banana\banana.79.jpg
# src data\snack\banana\10095_60_m_17.jpg
# dst sdata\snack\valid\banana\banana.80.jpg
# src data\snack\banana\10095_60_m_18.jpg
# dst sdata\snack\valid\banana\banana.81.jpg
# src data\snack\banana\10095_60_m_19.jpg
# dst sdata\snack\valid\banana\banana.82.jpg
# src data\snack\banana\10095_60_m_2.jpg
# dst sdata\snack\valid\banana\banana.83.jpg
# src data\snack\banana\10095_60_m_20.jpg
# dst sdata\snack\valid\banana\banana.84.jpg
# src data\snack\banana\10095_60_m_21.jpg
# dst sdata\snack\valid\banana\banana.85.jpg
# src data\snack\banana\10095_60_m_22.jpg
# dst sdata\snack\valid\banana\banana.86.jpg
# src data\snack\banana\10095_60_m_23.jpg
# dst sdata\snack\valid\banana\banana.87.jpg
# src data\snack\banana\10095_60_m_3.jpg
# dst sdata\snack\test\banana\banana.88.jpg
# src data\snack\banana\10095_60_m_4.jpg
# dst sdata\snack\test\banana\banana.89.jpg
# src data\snack\banana\10095_60_m_5.jpg
# dst sdata\snack\test\banana\banana.90.jpg
# src data\snack\banana\10095_60_m_6.jpg
# dst sdata\snack\test\banana\banana.91.jpg
# src data\snack\banana\10095_60_m_8.jpg
# dst sdata\snack\test\banana\banana.92.jpg
# src data\snack\banana\10095_60_m_9.jpg
# dst sdata\snack\test\banana\banana.93.jpg
# src data\snack\banana\10095_60_s_1.jpg
# dst sdata\snack\test\banana\banana.94.jpg
# src data\snack\banana\10095_60_s_10.jpg
# dst sdata\snack\test\banana\banana.95.jpg
# src data\snack\banana\10095_60_s_12.jpg
# dst sdata\snack\test\banana\banana.96.jpg
# src data\snack\banana\10095_60_s_14.jpg
# dst sdata\snack\test\banana\banana.97.jpg
# src data\snack\banana\10095_60_s_15.jpg
# dst sdata\snack\test\banana\banana.98.jpg
# src data\snack\banana\10095_60_s_17.jpg
# dst sdata\snack\test\banana\banana.99.jpg
# src data\snack\banana\10095_60_s_18.jpg
# dst sdata\snack\test\banana\banana.100.jpg
# src data\snack\banana\10095_60_s_19.jpg
# dst sdata\snack\test\banana\banana.101.jpg
# src data\snack\banana\10095_60_s_2.jpg
# dst sdata\snack\test\banana\banana.102.jpg
# src data\snack\banana\10095_60_s_20.jpg
# dst sdata\snack\test\banana\banana.103.jpg
# src data\snack\banana\10095_60_s_22.jpg
# dst sdata\snack\test\banana\banana.104.jpg
# src data\snack\banana\10095_60_s_23.jpg
# dst sdata\snack\test\banana\banana.105.jpg
# src data\snack\banana\10095_60_s_24.jpg
# dst sdata\snack\test\banana\banana.106.jpg
# src data\snack\banana\10095_60_s_3.jpg
# dst sdata\snack\test\banana\banana.107.jpg
# src data\snack\banana\10095_60_s_4.jpg
# dst sdata\snack\test\banana\banana.108.jpg
# src data\snack\banana\10095_60_s_5.jpg
# dst sdata\snack\test\banana\banana.109.jpg
# src data\snack\banana\10095_60_s_6.jpg
# dst sdata\snack\test\banana\banana.110.jpg
# src data\snack\banana\10095_60_s_7.jpg
# dst sdata\snack\test\banana\banana.111.jpg
# src data\snack\blueberry\10060_0_m_1.jpg
# dst sdata\snack\train\blueberry\blueberry.0.jpg
# src data\snack\blueberry\10060_0_m_10.jpg
# dst sdata\snack\train\blueberry\blueberry.1.jpg
# src data\snack\blueberry\10060_0_m_11.jpg
# dst sdata\snack\train\blueberry\blueberry.2.jpg
# src data\snack\blueberry\10060_0_m_12.jpg
# dst sdata\snack\train\blueberry\blueberry.3.jpg
# src data\snack\blueberry\10060_0_m_13.jpg
# dst sdata\snack\train\blueberry\blueberry.4.jpg
# src data\snack\blueberry\10060_0_m_14.jpg
# dst sdata\snack\train\blueberry\blueberry.5.jpg
# src data\snack\blueberry\10060_0_m_15.jpg
# dst sdata\snack\train\blueberry\blueberry.6.jpg
# src data\snack\blueberry\10060_0_m_16.jpg
# dst sdata\snack\train\blueberry\blueberry.7.jpg
# src data\snack\blueberry\10060_0_m_17.jpg
# dst sdata\snack\train\blueberry\blueberry.8.jpg
# src data\snack\blueberry\10060_0_m_19.jpg
# dst sdata\snack\train\blueberry\blueberry.9.jpg
# src data\snack\blueberry\10060_0_m_2.jpg
# dst sdata\snack\train\blueberry\blueberry.10.jpg
# src data\snack\blueberry\10060_0_m_21.jpg
# dst sdata\snack\train\blueberry\blueberry.11.jpg
# src data\snack\blueberry\10060_0_m_22.jpg
# dst sdata\snack\train\blueberry\blueberry.12.jpg
# src data\snack\blueberry\10060_0_m_23.jpg
# dst sdata\snack\train\blueberry\blueberry.13.jpg
# src data\snack\blueberry\10060_0_m_24.jpg
# dst sdata\snack\train\blueberry\blueberry.14.jpg
# src data\snack\blueberry\10060_0_m_3.jpg
# dst sdata\snack\train\blueberry\blueberry.15.jpg
# src data\snack\blueberry\10060_0_m_4.jpg
# dst sdata\snack\train\blueberry\blueberry.16.jpg
# src data\snack\blueberry\10060_0_m_6.jpg
# dst sdata\snack\train\blueberry\blueberry.17.jpg
# src data\snack\blueberry\10060_0_m_7.jpg
# dst sdata\snack\train\blueberry\blueberry.18.jpg
# src data\snack\blueberry\10060_0_s_1.jpg
# dst sdata\snack\train\blueberry\blueberry.19.jpg
# src data\snack\blueberry\10060_0_s_10.jpg
# dst sdata\snack\train\blueberry\blueberry.20.jpg
# src data\snack\blueberry\10060_0_s_11.jpg
# dst sdata\snack\train\blueberry\blueberry.21.jpg
# src data\snack\blueberry\10060_0_s_12.jpg
# dst sdata\snack\train\blueberry\blueberry.22.jpg
# src data\snack\blueberry\10060_0_s_14.jpg
# dst sdata\snack\train\blueberry\blueberry.23.jpg
# src data\snack\blueberry\10060_0_s_16.jpg
# dst sdata\snack\train\blueberry\blueberry.24.jpg
# src data\snack\blueberry\10060_0_s_17.jpg
# dst sdata\snack\train\blueberry\blueberry.25.jpg
# src data\snack\blueberry\10060_0_s_18.jpg
# dst sdata\snack\train\blueberry\blueberry.26.jpg
# src data\snack\blueberry\10060_0_s_19.jpg
# dst sdata\snack\train\blueberry\blueberry.27.jpg
# src data\snack\blueberry\10060_0_s_2.jpg
# dst sdata\snack\train\blueberry\blueberry.28.jpg
# src data\snack\blueberry\10060_0_s_20.jpg
# dst sdata\snack\train\blueberry\blueberry.29.jpg
# src data\snack\blueberry\10060_0_s_21.jpg
# dst sdata\snack\train\blueberry\blueberry.30.jpg
# src data\snack\blueberry\10060_0_s_22.jpg
# dst sdata\snack\train\blueberry\blueberry.31.jpg
# src data\snack\blueberry\10060_0_s_23.jpg
# dst sdata\snack\train\blueberry\blueberry.32.jpg
# src data\snack\blueberry\10060_0_s_24.jpg
# dst sdata\snack\train\blueberry\blueberry.33.jpg
# src data\snack\blueberry\10060_0_s_3.jpg
# dst sdata\snack\train\blueberry\blueberry.34.jpg
# src data\snack\blueberry\10060_0_s_4.jpg
# dst sdata\snack\train\blueberry\blueberry.35.jpg
# src data\snack\blueberry\10060_0_s_5.jpg
# dst sdata\snack\train\blueberry\blueberry.36.jpg
# src data\snack\blueberry\10060_0_s_6.jpg
# dst sdata\snack\train\blueberry\blueberry.37.jpg
# src data\snack\blueberry\10060_0_s_7.jpg
# dst sdata\snack\train\blueberry\blueberry.38.jpg
# src data\snack\blueberry\10060_0_s_8.jpg
# dst sdata\snack\train\blueberry\blueberry.39.jpg
# src data\snack\blueberry\10060_0_s_9.jpg
# dst sdata\snack\train\blueberry\blueberry.40.jpg
# src data\snack\blueberry\10060_30_m_11.jpg
# dst sdata\snack\train\blueberry\blueberry.41.jpg
# src data\snack\blueberry\10060_30_m_13.jpg
# dst sdata\snack\train\blueberry\blueberry.42.jpg
# src data\snack\blueberry\10060_30_m_15.jpg
# dst sdata\snack\train\blueberry\blueberry.43.jpg
# src data\snack\blueberry\10060_30_m_17.jpg
# dst sdata\snack\train\blueberry\blueberry.44.jpg
# src data\snack\blueberry\10060_30_m_18.jpg
# dst sdata\snack\train\blueberry\blueberry.45.jpg
# src data\snack\blueberry\10060_30_m_19.jpg
# dst sdata\snack\train\blueberry\blueberry.46.jpg
# src data\snack\blueberry\10060_30_m_2.jpg
# dst sdata\snack\train\blueberry\blueberry.47.jpg
# src data\snack\blueberry\10060_30_m_21.jpg
# dst sdata\snack\train\blueberry\blueberry.48.jpg
# src data\snack\blueberry\10060_30_m_23.jpg
# dst sdata\snack\train\blueberry\blueberry.49.jpg
# src data\snack\blueberry\10060_30_m_3.jpg
# dst sdata\snack\train\blueberry\blueberry.50.jpg
# src data\snack\blueberry\10060_30_m_4.jpg
# dst sdata\snack\train\blueberry\blueberry.51.jpg
# src data\snack\blueberry\10060_30_m_5.jpg
# dst sdata\snack\train\blueberry\blueberry.52.jpg
# src data\snack\blueberry\10060_30_m_6.jpg
# dst sdata\snack\train\blueberry\blueberry.53.jpg
# src data\snack\blueberry\10060_30_m_7.jpg
# dst sdata\snack\train\blueberry\blueberry.54.jpg
# src data\snack\blueberry\10060_30_m_8.jpg
# dst sdata\snack\train\blueberry\blueberry.55.jpg
# src data\snack\blueberry\10060_30_m_9.jpg
# dst sdata\snack\train\blueberry\blueberry.56.jpg
# src data\snack\blueberry\10060_30_s_10.jpg
# dst sdata\snack\train\blueberry\blueberry.57.jpg
# src data\snack\blueberry\10060_30_s_11.jpg
# dst sdata\snack\train\blueberry\blueberry.58.jpg
# src data\snack\blueberry\10060_30_s_12.jpg
# dst sdata\snack\train\blueberry\blueberry.59.jpg
# src data\snack\blueberry\10060_30_s_14.jpg
# dst sdata\snack\train\blueberry\blueberry.60.jpg
# src data\snack\blueberry\10060_30_s_15.jpg
# dst sdata\snack\train\blueberry\blueberry.61.jpg
# src data\snack\blueberry\10060_30_s_16.jpg
# dst sdata\snack\train\blueberry\blueberry.62.jpg
# src data\snack\blueberry\10060_30_s_17.jpg
# dst sdata\snack\train\blueberry\blueberry.63.jpg
# src data\snack\blueberry\10060_30_s_18.jpg
# dst sdata\snack\train\blueberry\blueberry.64.jpg
# src data\snack\blueberry\10060_30_s_19.jpg
# dst sdata\snack\train\blueberry\blueberry.65.jpg
# src data\snack\blueberry\10060_30_s_2.jpg
# dst sdata\snack\train\blueberry\blueberry.66.jpg
# src data\snack\blueberry\10060_30_s_20.jpg
# dst sdata\snack\valid\blueberry\blueberry.67.jpg
# src data\snack\blueberry\10060_30_s_21.jpg
# dst sdata\snack\valid\blueberry\blueberry.68.jpg
# src data\snack\blueberry\10060_30_s_22.jpg
# dst sdata\snack\valid\blueberry\blueberry.69.jpg
# src data\snack\blueberry\10060_30_s_23.jpg
# dst sdata\snack\valid\blueberry\blueberry.70.jpg
# src data\snack\blueberry\10060_30_s_24.jpg
# dst sdata\snack\valid\blueberry\blueberry.71.jpg
# src data\snack\blueberry\10060_30_s_3.jpg
# dst sdata\snack\valid\blueberry\blueberry.72.jpg
# src data\snack\blueberry\10060_30_s_4.jpg
# dst sdata\snack\valid\blueberry\blueberry.73.jpg
# src data\snack\blueberry\10060_30_s_5.jpg
# dst sdata\snack\valid\blueberry\blueberry.74.jpg
# src data\snack\blueberry\10060_30_s_6.jpg
# dst sdata\snack\valid\blueberry\blueberry.75.jpg
# src data\snack\blueberry\10060_30_s_7.jpg
# dst sdata\snack\valid\blueberry\blueberry.76.jpg
# src data\snack\blueberry\10060_30_s_9.jpg
# dst sdata\snack\valid\blueberry\blueberry.77.jpg
# src data\snack\blueberry\10060_60_m_1.jpg
# dst sdata\snack\valid\blueberry\blueberry.78.jpg
# src data\snack\blueberry\10060_60_m_10.jpg
# dst sdata\snack\valid\blueberry\blueberry.79.jpg
# src data\snack\blueberry\10060_60_m_11.jpg
# dst sdata\snack\valid\blueberry\blueberry.80.jpg
# src data\snack\blueberry\10060_60_m_12.jpg
# dst sdata\snack\valid\blueberry\blueberry.81.jpg
# src data\snack\blueberry\10060_60_m_13.jpg
# dst sdata\snack\valid\blueberry\blueberry.82.jpg
# src data\snack\blueberry\10060_60_m_14.jpg
# dst sdata\snack\valid\blueberry\blueberry.83.jpg
# src data\snack\blueberry\10060_60_m_15.jpg
# dst sdata\snack\valid\blueberry\blueberry.84.jpg
# src data\snack\blueberry\10060_60_m_16.jpg
# dst sdata\snack\valid\blueberry\blueberry.85.jpg
# src data\snack\blueberry\10060_60_m_18.jpg
# dst sdata\snack\valid\blueberry\blueberry.86.jpg
# src data\snack\blueberry\10060_60_m_2.jpg
# dst sdata\snack\valid\blueberry\blueberry.87.jpg
# src data\snack\blueberry\10060_60_m_20.jpg
# dst sdata\snack\test\blueberry\blueberry.88.jpg
# src data\snack\blueberry\10060_60_m_23.jpg
# dst sdata\snack\test\blueberry\blueberry.89.jpg
# src data\snack\blueberry\10060_60_m_4.jpg
# dst sdata\snack\test\blueberry\blueberry.90.jpg
# src data\snack\blueberry\10060_60_m_5.jpg
# dst sdata\snack\test\blueberry\blueberry.91.jpg
# src data\snack\blueberry\10060_60_m_6.jpg
# dst sdata\snack\test\blueberry\blueberry.92.jpg
# src data\snack\blueberry\10060_60_m_7.jpg
# dst sdata\snack\test\blueberry\blueberry.93.jpg
# src data\snack\blueberry\10060_60_m_8.jpg
# dst sdata\snack\test\blueberry\blueberry.94.jpg
# src data\snack\blueberry\10060_60_m_9.jpg
# dst sdata\snack\test\blueberry\blueberry.95.jpg
# src data\snack\blueberry\10060_60_s_1.jpg
# dst sdata\snack\test\blueberry\blueberry.96.jpg
# src data\snack\blueberry\10060_60_s_11.jpg
# dst sdata\snack\test\blueberry\blueberry.97.jpg
# src data\snack\blueberry\10060_60_s_12.jpg
# dst sdata\snack\test\blueberry\blueberry.98.jpg
# src data\snack\blueberry\10060_60_s_13.jpg
# dst sdata\snack\test\blueberry\blueberry.99.jpg
# src data\snack\blueberry\10060_60_s_14.jpg
# dst sdata\snack\test\blueberry\blueberry.100.jpg
# src data\snack\blueberry\10060_60_s_15.jpg
# dst sdata\snack\test\blueberry\blueberry.101.jpg
# src data\snack\blueberry\10060_60_s_16.jpg
# dst sdata\snack\test\blueberry\blueberry.102.jpg
# src data\snack\blueberry\10060_60_s_18.jpg
# dst sdata\snack\test\blueberry\blueberry.103.jpg
# src data\snack\blueberry\10060_60_s_2.jpg
# dst sdata\snack\test\blueberry\blueberry.104.jpg
# src data\snack\blueberry\10060_60_s_20.jpg
# dst sdata\snack\test\blueberry\blueberry.105.jpg
# src data\snack\blueberry\10060_60_s_22.jpg
# dst sdata\snack\test\blueberry\blueberry.106.jpg
# src data\snack\blueberry\10060_60_s_23.jpg
# dst sdata\snack\test\blueberry\blueberry.107.jpg
# src data\snack\blueberry\10060_60_s_24.jpg
# dst sdata\snack\test\blueberry\blueberry.108.jpg
# src data\snack\blueberry\10060_60_s_3.jpg
# dst sdata\snack\test\blueberry\blueberry.109.jpg
# src data\snack\blueberry\10060_60_s_4.jpg
# dst sdata\snack\test\blueberry\blueberry.110.jpg
# src data\snack\blueberry\10060_60_s_6.jpg
# dst sdata\snack\test\blueberry\blueberry.111.jpg
# src data\snack\choco\10094_0_m_1.jpg
# dst sdata\snack\train\choco\choco.0.jpg
# src data\snack\choco\10094_0_m_10.jpg
# dst sdata\snack\train\choco\choco.1.jpg
# src data\snack\choco\10094_0_m_11.jpg
# dst sdata\snack\train\choco\choco.2.jpg
# src data\snack\choco\10094_0_m_12.jpg
# dst sdata\snack\train\choco\choco.3.jpg
# src data\snack\choco\10094_0_m_13.jpg
# dst sdata\snack\train\choco\choco.4.jpg
# src data\snack\choco\10094_0_m_14.jpg
# dst sdata\snack\train\choco\choco.5.jpg
# src data\snack\choco\10094_0_m_15.jpg
# dst sdata\snack\train\choco\choco.6.jpg
# src data\snack\choco\10094_0_m_16.jpg
# dst sdata\snack\train\choco\choco.7.jpg
# src data\snack\choco\10094_0_m_17.jpg
# dst sdata\snack\train\choco\choco.8.jpg
# src data\snack\choco\10094_0_m_18.jpg
# dst sdata\snack\train\choco\choco.9.jpg
# src data\snack\choco\10094_0_m_2.jpg
# dst sdata\snack\train\choco\choco.10.jpg
# src data\snack\choco\10094_0_m_21.jpg
# dst sdata\snack\train\choco\choco.11.jpg
# src data\snack\choco\10094_0_m_22.jpg
# dst sdata\snack\train\choco\choco.12.jpg
# src data\snack\choco\10094_0_m_23.jpg
# dst sdata\snack\train\choco\choco.13.jpg
# src data\snack\choco\10094_0_m_3.jpg
# dst sdata\snack\train\choco\choco.14.jpg
# src data\snack\choco\10094_0_m_4.jpg
# dst sdata\snack\train\choco\choco.15.jpg
# src data\snack\choco\10094_0_m_5.jpg
# dst sdata\snack\train\choco\choco.16.jpg
# src data\snack\choco\10094_0_m_6.jpg
# dst sdata\snack\train\choco\choco.17.jpg
# src data\snack\choco\10094_0_m_7.jpg
# dst sdata\snack\train\choco\choco.18.jpg
# src data\snack\choco\10094_0_m_8.jpg
# dst sdata\snack\train\choco\choco.19.jpg
# src data\snack\choco\10094_0_m_9.jpg
# dst sdata\snack\train\choco\choco.20.jpg
# src data\snack\choco\10094_0_s_1.jpg
# dst sdata\snack\train\choco\choco.21.jpg
# src data\snack\choco\10094_0_s_12.jpg
# dst sdata\snack\train\choco\choco.22.jpg
# src data\snack\choco\10094_0_s_13.jpg
# dst sdata\snack\train\choco\choco.23.jpg
# src data\snack\choco\10094_0_s_14.jpg
# dst sdata\snack\train\choco\choco.24.jpg
# src data\snack\choco\10094_0_s_15.jpg
# dst sdata\snack\train\choco\choco.25.jpg
# src data\snack\choco\10094_0_s_16.jpg
# dst sdata\snack\train\choco\choco.26.jpg
# src data\snack\choco\10094_0_s_18.jpg
# dst sdata\snack\train\choco\choco.27.jpg
# src data\snack\choco\10094_0_s_19.jpg
# dst sdata\snack\train\choco\choco.28.jpg
# src data\snack\choco\10094_0_s_2.jpg
# dst sdata\snack\train\choco\choco.29.jpg
# src data\snack\choco\10094_0_s_20.jpg
# dst sdata\snack\train\choco\choco.30.jpg
# src data\snack\choco\10094_0_s_21.jpg
# dst sdata\snack\train\choco\choco.31.jpg
# src data\snack\choco\10094_0_s_22.jpg
# dst sdata\snack\train\choco\choco.32.jpg
# src data\snack\choco\10094_0_s_23.jpg
# dst sdata\snack\train\choco\choco.33.jpg
# src data\snack\choco\10094_0_s_3.jpg
# dst sdata\snack\train\choco\choco.34.jpg
# src data\snack\choco\10094_0_s_4.jpg
# dst sdata\snack\train\choco\choco.35.jpg
# src data\snack\choco\10094_0_s_6.jpg
# dst sdata\snack\train\choco\choco.36.jpg
# src data\snack\choco\10094_0_s_7.jpg
# dst sdata\snack\train\choco\choco.37.jpg
# src data\snack\choco\10094_0_s_8.jpg
# dst sdata\snack\train\choco\choco.38.jpg
# src data\snack\choco\10094_0_s_9.jpg
# dst sdata\snack\train\choco\choco.39.jpg
# src data\snack\choco\10094_30_m_1.jpg
# dst sdata\snack\train\choco\choco.40.jpg
# src data\snack\choco\10094_30_m_13.jpg
# dst sdata\snack\train\choco\choco.41.jpg
# src data\snack\choco\10094_30_m_14.jpg
# dst sdata\snack\train\choco\choco.42.jpg
# src data\snack\choco\10094_30_m_15.jpg
# dst sdata\snack\train\choco\choco.43.jpg
# src data\snack\choco\10094_30_m_16.jpg
# dst sdata\snack\train\choco\choco.44.jpg
# src data\snack\choco\10094_30_m_17.jpg
# dst sdata\snack\train\choco\choco.45.jpg
# src data\snack\choco\10094_30_m_18.jpg
# dst sdata\snack\train\choco\choco.46.jpg
# src data\snack\choco\10094_30_m_19.jpg
# dst sdata\snack\train\choco\choco.47.jpg
# src data\snack\choco\10094_30_m_2.jpg
# dst sdata\snack\train\choco\choco.48.jpg
# src data\snack\choco\10094_30_m_20.jpg
# dst sdata\snack\train\choco\choco.49.jpg
# src data\snack\choco\10094_30_m_24.jpg
# dst sdata\snack\train\choco\choco.50.jpg
# src data\snack\choco\10094_30_m_3.jpg
# dst sdata\snack\train\choco\choco.51.jpg
# src data\snack\choco\10094_30_m_4.jpg
# dst sdata\snack\train\choco\choco.52.jpg
# src data\snack\choco\10094_30_m_5.jpg
# dst sdata\snack\train\choco\choco.53.jpg
# src data\snack\choco\10094_30_m_6.jpg
# dst sdata\snack\train\choco\choco.54.jpg
# src data\snack\choco\10094_30_m_8.jpg
# dst sdata\snack\train\choco\choco.55.jpg
# src data\snack\choco\10094_30_m_9.jpg
# dst sdata\snack\train\choco\choco.56.jpg
# src data\snack\choco\10094_30_s_1.jpg
# dst sdata\snack\train\choco\choco.57.jpg
# src data\snack\choco\10094_30_s_10.jpg
# dst sdata\snack\train\choco\choco.58.jpg
# src data\snack\choco\10094_30_s_11.jpg
# dst sdata\snack\train\choco\choco.59.jpg
# src data\snack\choco\10094_30_s_12.jpg
# dst sdata\snack\train\choco\choco.60.jpg
# src data\snack\choco\10094_30_s_15.jpg
# dst sdata\snack\train\choco\choco.61.jpg
# src data\snack\choco\10094_30_s_16.jpg
# dst sdata\snack\train\choco\choco.62.jpg
# src data\snack\choco\10094_30_s_17.jpg
# dst sdata\snack\train\choco\choco.63.jpg
# src data\snack\choco\10094_30_s_19.jpg
# dst sdata\snack\train\choco\choco.64.jpg
# src data\snack\choco\10094_30_s_2.jpg
# dst sdata\snack\train\choco\choco.65.jpg
# src data\snack\choco\10094_30_s_21.jpg
# dst sdata\snack\train\choco\choco.66.jpg
# src data\snack\choco\10094_30_s_22.jpg
# dst sdata\snack\valid\choco\choco.67.jpg
# src data\snack\choco\10094_30_s_23.jpg
# dst sdata\snack\valid\choco\choco.68.jpg
# src data\snack\choco\10094_30_s_24.jpg
# dst sdata\snack\valid\choco\choco.69.jpg
# src data\snack\choco\10094_30_s_5.jpg
# dst sdata\snack\valid\choco\choco.70.jpg
# src data\snack\choco\10094_30_s_6.jpg
# dst sdata\snack\valid\choco\choco.71.jpg
# src data\snack\choco\10094_30_s_7.jpg
# dst sdata\snack\valid\choco\choco.72.jpg
# src data\snack\choco\10094_30_s_8.jpg
# dst sdata\snack\valid\choco\choco.73.jpg
# src data\snack\choco\10094_30_s_9.jpg
# dst sdata\snack\valid\choco\choco.74.jpg
# src data\snack\choco\10094_60_m_1.jpg
# dst sdata\snack\valid\choco\choco.75.jpg
# src data\snack\choco\10094_60_m_11.jpg
# dst sdata\snack\valid\choco\choco.76.jpg
# src data\snack\choco\10094_60_m_12.jpg
# dst sdata\snack\valid\choco\choco.77.jpg
# src data\snack\choco\10094_60_m_14.jpg
# dst sdata\snack\valid\choco\choco.78.jpg
# src data\snack\choco\10094_60_m_16.jpg
# dst sdata\snack\valid\choco\choco.79.jpg
# src data\snack\choco\10094_60_m_18.jpg
# dst sdata\snack\valid\choco\choco.80.jpg
# src data\snack\choco\10094_60_m_2.jpg
# dst sdata\snack\valid\choco\choco.81.jpg
# src data\snack\choco\10094_60_m_20.jpg
# dst sdata\snack\valid\choco\choco.82.jpg
# src data\snack\choco\10094_60_m_21.jpg
# dst sdata\snack\valid\choco\choco.83.jpg
# src data\snack\choco\10094_60_m_23.jpg
# dst sdata\snack\valid\choco\choco.84.jpg
# src data\snack\choco\10094_60_m_3.jpg
# dst sdata\snack\valid\choco\choco.85.jpg
# src data\snack\choco\10094_60_m_4.jpg
# dst sdata\snack\valid\choco\choco.86.jpg
# src data\snack\choco\10094_60_m_5.jpg
# dst sdata\snack\valid\choco\choco.87.jpg
# src data\snack\choco\10094_60_m_6.jpg
# dst sdata\snack\test\choco\choco.88.jpg
# src data\snack\choco\10094_60_m_7.jpg
# dst sdata\snack\test\choco\choco.89.jpg
# src data\snack\choco\10094_60_m_8.jpg
# dst sdata\snack\test\choco\choco.90.jpg
# src data\snack\choco\10094_60_m_9.jpg
# dst sdata\snack\test\choco\choco.91.jpg
# src data\snack\choco\10094_60_s_1.jpg
# dst sdata\snack\test\choco\choco.92.jpg
# src data\snack\choco\10094_60_s_10.jpg
# dst sdata\snack\test\choco\choco.93.jpg
# src data\snack\choco\10094_60_s_11.jpg
# dst sdata\snack\test\choco\choco.94.jpg
# src data\snack\choco\10094_60_s_12.jpg
# dst sdata\snack\test\choco\choco.95.jpg
# src data\snack\choco\10094_60_s_14.jpg
# dst sdata\snack\test\choco\choco.96.jpg
# src data\snack\choco\10094_60_s_15.jpg
# dst sdata\snack\test\choco\choco.97.jpg
# src data\snack\choco\10094_60_s_16.jpg
# dst sdata\snack\test\choco\choco.98.jpg
# src data\snack\choco\10094_60_s_17.jpg
# dst sdata\snack\test\choco\choco.99.jpg
# src data\snack\choco\10094_60_s_18.jpg
# dst sdata\snack\test\choco\choco.100.jpg
# src data\snack\choco\10094_60_s_19.jpg
# dst sdata\snack\test\choco\choco.101.jpg
# src data\snack\choco\10094_60_s_2.jpg
# dst sdata\snack\test\choco\choco.102.jpg
# src data\snack\choco\10094_60_s_20.jpg
# dst sdata\snack\test\choco\choco.103.jpg
# src data\snack\choco\10094_60_s_21.jpg
# dst sdata\snack\test\choco\choco.104.jpg
# src data\snack\choco\10094_60_s_22.jpg
# dst sdata\snack\test\choco\choco.105.jpg
# src data\snack\choco\10094_60_s_23.jpg
# dst sdata\snack\test\choco\choco.106.jpg
# src data\snack\choco\10094_60_s_24.jpg
# dst sdata\snack\test\choco\choco.107.jpg
# src data\snack\choco\10094_60_s_3.jpg
# dst sdata\snack\test\choco\choco.108.jpg
# src data\snack\choco\10094_60_s_4.jpg
# dst sdata\snack\test\choco\choco.109.jpg
# src data\snack\choco\10094_60_s_5.jpg
# dst sdata\snack\test\choco\choco.110.jpg
# src data\snack\choco\10094_60_s_6.jpg
# dst sdata\snack\test\choco\choco.111.jpg
# src data\snack\cone\10091_0_m_1.jpg
# dst sdata\snack\train\cone\cone.0.jpg
# src data\snack\cone\10091_0_m_10.jpg
# dst sdata\snack\train\cone\cone.1.jpg
# src data\snack\cone\10091_0_m_11.jpg
# dst sdata\snack\train\cone\cone.2.jpg
# src data\snack\cone\10091_0_m_12.jpg
# dst sdata\snack\train\cone\cone.3.jpg
# src data\snack\cone\10091_0_m_14.jpg
# dst sdata\snack\train\cone\cone.4.jpg
# src data\snack\cone\10091_0_m_15.jpg
# dst sdata\snack\train\cone\cone.5.jpg
# src data\snack\cone\10091_0_m_16.jpg
# dst sdata\snack\train\cone\cone.6.jpg
# src data\snack\cone\10091_0_m_17.jpg
# dst sdata\snack\train\cone\cone.7.jpg
# src data\snack\cone\10091_0_m_19.jpg
# dst sdata\snack\train\cone\cone.8.jpg
# src data\snack\cone\10091_0_m_2.jpg
# dst sdata\snack\train\cone\cone.9.jpg
# src data\snack\cone\10091_0_m_20.jpg
# dst sdata\snack\train\cone\cone.10.jpg
# src data\snack\cone\10091_0_m_21.jpg
# dst sdata\snack\train\cone\cone.11.jpg
# src data\snack\cone\10091_0_m_22.jpg
# dst sdata\snack\train\cone\cone.12.jpg
# src data\snack\cone\10091_0_m_23.jpg
# dst sdata\snack\train\cone\cone.13.jpg
# src data\snack\cone\10091_0_m_24.jpg
# dst sdata\snack\train\cone\cone.14.jpg
# src data\snack\cone\10091_0_m_3.jpg
# dst sdata\snack\train\cone\cone.15.jpg
# src data\snack\cone\10091_0_m_4.jpg
# dst sdata\snack\train\cone\cone.16.jpg
# src data\snack\cone\10091_0_m_5.jpg
# dst sdata\snack\train\cone\cone.17.jpg
# src data\snack\cone\10091_0_m_7.jpg
# dst sdata\snack\train\cone\cone.18.jpg
# src data\snack\cone\10091_0_m_9.jpg
# dst sdata\snack\train\cone\cone.19.jpg
# src data\snack\cone\10091_0_s_1.jpg
# dst sdata\snack\train\cone\cone.20.jpg
# src data\snack\cone\10091_0_s_12.jpg
# dst sdata\snack\train\cone\cone.21.jpg
# src data\snack\cone\10091_0_s_14.jpg
# dst sdata\snack\train\cone\cone.22.jpg
# src data\snack\cone\10091_0_s_16.jpg
# dst sdata\snack\train\cone\cone.23.jpg
# src data\snack\cone\10091_0_s_17.jpg
# dst sdata\snack\train\cone\cone.24.jpg
# src data\snack\cone\10091_0_s_18.jpg
# dst sdata\snack\train\cone\cone.25.jpg
# src data\snack\cone\10091_0_s_19.jpg
# dst sdata\snack\train\cone\cone.26.jpg
# src data\snack\cone\10091_0_s_2.jpg
# dst sdata\snack\train\cone\cone.27.jpg
# src data\snack\cone\10091_0_s_20.jpg
# dst sdata\snack\train\cone\cone.28.jpg
# src data\snack\cone\10091_0_s_21.jpg
# dst sdata\snack\train\cone\cone.29.jpg
# src data\snack\cone\10091_0_s_22.jpg
# dst sdata\snack\train\cone\cone.30.jpg
# src data\snack\cone\10091_0_s_23.jpg
# dst sdata\snack\train\cone\cone.31.jpg
# src data\snack\cone\10091_0_s_3.jpg
# dst sdata\snack\train\cone\cone.32.jpg
# src data\snack\cone\10091_0_s_4.jpg
# dst sdata\snack\train\cone\cone.33.jpg
# src data\snack\cone\10091_0_s_5.jpg
# dst sdata\snack\train\cone\cone.34.jpg
# src data\snack\cone\10091_0_s_6.jpg
# dst sdata\snack\train\cone\cone.35.jpg
# src data\snack\cone\10091_0_s_8.jpg
# dst sdata\snack\train\cone\cone.36.jpg
# src data\snack\cone\10091_0_s_9.jpg
# dst sdata\snack\train\cone\cone.37.jpg
# src data\snack\cone\10091_30_m_1.jpg
# dst sdata\snack\train\cone\cone.38.jpg
# src data\snack\cone\10091_30_m_10.jpg
# dst sdata\snack\train\cone\cone.39.jpg
# src data\snack\cone\10091_30_m_12.jpg
# dst sdata\snack\train\cone\cone.40.jpg
# src data\snack\cone\10091_30_m_13.jpg
# dst sdata\snack\train\cone\cone.41.jpg
# src data\snack\cone\10091_30_m_14.jpg
# dst sdata\snack\train\cone\cone.42.jpg
# src data\snack\cone\10091_30_m_16.jpg
# dst sdata\snack\train\cone\cone.43.jpg
# src data\snack\cone\10091_30_m_19.jpg
# dst sdata\snack\train\cone\cone.44.jpg
# src data\snack\cone\10091_30_m_2.jpg
# dst sdata\snack\train\cone\cone.45.jpg
# src data\snack\cone\10091_30_m_20.jpg
# dst sdata\snack\train\cone\cone.46.jpg
# src data\snack\cone\10091_30_m_21.jpg
# dst sdata\snack\train\cone\cone.47.jpg
# src data\snack\cone\10091_30_m_22.jpg
# dst sdata\snack\train\cone\cone.48.jpg
# src data\snack\cone\10091_30_m_4.jpg
# dst sdata\snack\train\cone\cone.49.jpg
# src data\snack\cone\10091_30_m_5.jpg
# dst sdata\snack\train\cone\cone.50.jpg
# src data\snack\cone\10091_30_m_6.jpg
# dst sdata\snack\train\cone\cone.51.jpg
# src data\snack\cone\10091_30_m_7.jpg
# dst sdata\snack\train\cone\cone.52.jpg
# src data\snack\cone\10091_30_m_8.jpg
# dst sdata\snack\train\cone\cone.53.jpg
# src data\snack\cone\10091_30_m_9.jpg
# dst sdata\snack\train\cone\cone.54.jpg
# src data\snack\cone\10091_30_s_1.jpg
# dst sdata\snack\train\cone\cone.55.jpg
# src data\snack\cone\10091_30_s_10.jpg
# dst sdata\snack\train\cone\cone.56.jpg
# src data\snack\cone\10091_30_s_11.jpg
# dst sdata\snack\train\cone\cone.57.jpg
# src data\snack\cone\10091_30_s_15.jpg
# dst sdata\snack\train\cone\cone.58.jpg
# src data\snack\cone\10091_30_s_16.jpg
# dst sdata\snack\train\cone\cone.59.jpg
# src data\snack\cone\10091_30_s_17.jpg
# dst sdata\snack\train\cone\cone.60.jpg
# src data\snack\cone\10091_30_s_18.jpg
# dst sdata\snack\train\cone\cone.61.jpg
# src data\snack\cone\10091_30_s_19.jpg
# dst sdata\snack\train\cone\cone.62.jpg
# src data\snack\cone\10091_30_s_2.jpg
# dst sdata\snack\train\cone\cone.63.jpg
# src data\snack\cone\10091_30_s_20.jpg
# dst sdata\snack\train\cone\cone.64.jpg
# src data\snack\cone\10091_30_s_21.jpg
# dst sdata\snack\train\cone\cone.65.jpg
# src data\snack\cone\10091_30_s_22.jpg
# dst sdata\snack\train\cone\cone.66.jpg
# src data\snack\cone\10091_30_s_23.jpg
# dst sdata\snack\valid\cone\cone.67.jpg
# src data\snack\cone\10091_30_s_3.jpg
# dst sdata\snack\valid\cone\cone.68.jpg
# src data\snack\cone\10091_30_s_4.jpg
# dst sdata\snack\valid\cone\cone.69.jpg
# src data\snack\cone\10091_30_s_5.jpg
# dst sdata\snack\valid\cone\cone.70.jpg
# src data\snack\cone\10091_30_s_6.jpg
# dst sdata\snack\valid\cone\cone.71.jpg
# src data\snack\cone\10091_30_s_7.jpg
# dst sdata\snack\valid\cone\cone.72.jpg
# src data\snack\cone\10091_30_s_8.jpg
# dst sdata\snack\valid\cone\cone.73.jpg
# src data\snack\cone\10091_30_s_9.jpg
# dst sdata\snack\valid\cone\cone.74.jpg
# src data\snack\cone\10091_60_m_1.jpg
# dst sdata\snack\valid\cone\cone.75.jpg
# src data\snack\cone\10091_60_m_10.jpg
# dst sdata\snack\valid\cone\cone.76.jpg
# src data\snack\cone\10091_60_m_11.jpg
# dst sdata\snack\valid\cone\cone.77.jpg
# src data\snack\cone\10091_60_m_12.jpg
# dst sdata\snack\valid\cone\cone.78.jpg
# src data\snack\cone\10091_60_m_13.jpg
# dst sdata\snack\valid\cone\cone.79.jpg
# src data\snack\cone\10091_60_m_15.jpg
# dst sdata\snack\valid\cone\cone.80.jpg
# src data\snack\cone\10091_60_m_16.jpg
# dst sdata\snack\valid\cone\cone.81.jpg
# src data\snack\cone\10091_60_m_17.jpg
# dst sdata\snack\valid\cone\cone.82.jpg
# src data\snack\cone\10091_60_m_19.jpg
# dst sdata\snack\valid\cone\cone.83.jpg
# src data\snack\cone\10091_60_m_21.jpg
# dst sdata\snack\valid\cone\cone.84.jpg
# src data\snack\cone\10091_60_m_22.jpg
# dst sdata\snack\valid\cone\cone.85.jpg
# src data\snack\cone\10091_60_m_23.jpg
# dst sdata\snack\valid\cone\cone.86.jpg
# src data\snack\cone\10091_60_m_24.jpg
# dst sdata\snack\valid\cone\cone.87.jpg
# src data\snack\cone\10091_60_m_3.jpg
# dst sdata\snack\test\cone\cone.88.jpg
# src data\snack\cone\10091_60_m_4.jpg
# dst sdata\snack\test\cone\cone.89.jpg
# src data\snack\cone\10091_60_m_5.jpg
# dst sdata\snack\test\cone\cone.90.jpg
# src data\snack\cone\10091_60_m_6.jpg
# dst sdata\snack\test\cone\cone.91.jpg
# src data\snack\cone\10091_60_m_7.jpg
# dst sdata\snack\test\cone\cone.92.jpg
# src data\snack\cone\10091_60_m_8.jpg
# dst sdata\snack\test\cone\cone.93.jpg
# src data\snack\cone\10091_60_m_9.jpg
# dst sdata\snack\test\cone\cone.94.jpg
# src data\snack\cone\10091_60_s_1.jpg
# dst sdata\snack\test\cone\cone.95.jpg
# src data\snack\cone\10091_60_s_11.jpg
# dst sdata\snack\test\cone\cone.96.jpg
# src data\snack\cone\10091_60_s_12.jpg
# dst sdata\snack\test\cone\cone.97.jpg
# src data\snack\cone\10091_60_s_13.jpg
# dst sdata\snack\test\cone\cone.98.jpg
# src data\snack\cone\10091_60_s_14.jpg
# dst sdata\snack\test\cone\cone.99.jpg
# src data\snack\cone\10091_60_s_15.jpg
# dst sdata\snack\test\cone\cone.100.jpg
# src data\snack\cone\10091_60_s_16.jpg
# dst sdata\snack\test\cone\cone.101.jpg
# src data\snack\cone\10091_60_s_17.jpg
# dst sdata\snack\test\cone\cone.102.jpg
# src data\snack\cone\10091_60_s_18.jpg
# dst sdata\snack\test\cone\cone.103.jpg
# src data\snack\cone\10091_60_s_19.jpg
# dst sdata\snack\test\cone\cone.104.jpg
# src data\snack\cone\10091_60_s_2.jpg
# dst sdata\snack\test\cone\cone.105.jpg
# src data\snack\cone\10091_60_s_20.jpg
# dst sdata\snack\test\cone\cone.106.jpg
# src data\snack\cone\10091_60_s_21.jpg
# dst sdata\snack\test\cone\cone.107.jpg
# src data\snack\cone\10091_60_s_23.jpg
# dst sdata\snack\test\cone\cone.108.jpg
# src data\snack\cone\10091_60_s_24.jpg
# dst sdata\snack\test\cone\cone.109.jpg
# src data\snack\cone\10091_60_s_3.jpg
# dst sdata\snack\test\cone\cone.110.jpg
# src data\snack\cone\10091_60_s_5.jpg
# dst sdata\snack\test\cone\cone.111.jpg
# src data\snack\gum\10100_0_m_1.jpg
# dst sdata\snack\train\gum\gum.0.jpg
# src data\snack\gum\10100_0_m_11.jpg
# dst sdata\snack\train\gum\gum.1.jpg
# src data\snack\gum\10100_0_m_12.jpg
# dst sdata\snack\train\gum\gum.2.jpg
# src data\snack\gum\10100_0_m_13.jpg
# dst sdata\snack\train\gum\gum.3.jpg
# src data\snack\gum\10100_0_m_15.jpg
# dst sdata\snack\train\gum\gum.4.jpg
# src data\snack\gum\10100_0_m_16.jpg
# dst sdata\snack\train\gum\gum.5.jpg
# src data\snack\gum\10100_0_m_18.jpg
# dst sdata\snack\train\gum\gum.6.jpg
# src data\snack\gum\10100_0_m_19.jpg
# dst sdata\snack\train\gum\gum.7.jpg
# src data\snack\gum\10100_0_m_2.jpg
# dst sdata\snack\train\gum\gum.8.jpg
# src data\snack\gum\10100_0_m_20.jpg
# dst sdata\snack\train\gum\gum.9.jpg
# src data\snack\gum\10100_0_m_21.jpg
# dst sdata\snack\train\gum\gum.10.jpg
# src data\snack\gum\10100_0_m_23.jpg
# dst sdata\snack\train\gum\gum.11.jpg
# src data\snack\gum\10100_0_m_24.jpg
# dst sdata\snack\train\gum\gum.12.jpg
# src data\snack\gum\10100_0_m_4.jpg
# dst sdata\snack\train\gum\gum.13.jpg
# src data\snack\gum\10100_0_m_5.jpg
# dst sdata\snack\train\gum\gum.14.jpg
# src data\snack\gum\10100_0_m_6.jpg
# dst sdata\snack\train\gum\gum.15.jpg
# src data\snack\gum\10100_0_m_7.jpg
# dst sdata\snack\train\gum\gum.16.jpg
# src data\snack\gum\10100_0_m_8.jpg
# dst sdata\snack\train\gum\gum.17.jpg
# src data\snack\gum\10100_0_m_9.jpg
# dst sdata\snack\train\gum\gum.18.jpg
# src data\snack\gum\10100_0_s_1.jpg
# dst sdata\snack\train\gum\gum.19.jpg
# src data\snack\gum\10100_0_s_10.jpg
# dst sdata\snack\train\gum\gum.20.jpg
# src data\snack\gum\10100_0_s_11.jpg
# dst sdata\snack\train\gum\gum.21.jpg
# src data\snack\gum\10100_0_s_12.jpg
# dst sdata\snack\train\gum\gum.22.jpg
# src data\snack\gum\10100_0_s_13.jpg
# dst sdata\snack\train\gum\gum.23.jpg
# src data\snack\gum\10100_0_s_14.jpg
# dst sdata\snack\train\gum\gum.24.jpg
# src data\snack\gum\10100_0_s_15.jpg
# dst sdata\snack\train\gum\gum.25.jpg
# src data\snack\gum\10100_0_s_16.jpg
# dst sdata\snack\train\gum\gum.26.jpg
# src data\snack\gum\10100_0_s_17.jpg
# dst sdata\snack\train\gum\gum.27.jpg
# src data\snack\gum\10100_0_s_18.jpg
# dst sdata\snack\train\gum\gum.28.jpg
# src data\snack\gum\10100_0_s_19.jpg
# dst sdata\snack\train\gum\gum.29.jpg
# src data\snack\gum\10100_0_s_20.jpg
# dst sdata\snack\train\gum\gum.30.jpg
# src data\snack\gum\10100_0_s_21.jpg
# dst sdata\snack\train\gum\gum.31.jpg
# src data\snack\gum\10100_0_s_22.jpg
# dst sdata\snack\train\gum\gum.32.jpg
# src data\snack\gum\10100_0_s_23.jpg
# dst sdata\snack\train\gum\gum.33.jpg
# src data\snack\gum\10100_0_s_24.jpg
# dst sdata\snack\train\gum\gum.34.jpg
# src data\snack\gum\10100_0_s_4.jpg
# dst sdata\snack\train\gum\gum.35.jpg
# src data\snack\gum\10100_0_s_5.jpg
# dst sdata\snack\train\gum\gum.36.jpg
# src data\snack\gum\10100_0_s_6.jpg
# dst sdata\snack\train\gum\gum.37.jpg
# src data\snack\gum\10100_0_s_9.jpg
# dst sdata\snack\train\gum\gum.38.jpg
# src data\snack\gum\10100_30_m_1.jpg
# dst sdata\snack\train\gum\gum.39.jpg
# src data\snack\gum\10100_30_m_12.jpg
# dst sdata\snack\train\gum\gum.40.jpg
# src data\snack\gum\10100_30_m_13.jpg
# dst sdata\snack\train\gum\gum.41.jpg
# src data\snack\gum\10100_30_m_14.jpg
# dst sdata\snack\train\gum\gum.42.jpg
# src data\snack\gum\10100_30_m_15.jpg
# dst sdata\snack\train\gum\gum.43.jpg
# src data\snack\gum\10100_30_m_16.jpg
# dst sdata\snack\train\gum\gum.44.jpg
# src data\snack\gum\10100_30_m_18.jpg
# dst sdata\snack\train\gum\gum.45.jpg
# src data\snack\gum\10100_30_m_2.jpg
# dst sdata\snack\train\gum\gum.46.jpg
# src data\snack\gum\10100_30_m_20.jpg
# dst sdata\snack\train\gum\gum.47.jpg
# src data\snack\gum\10100_30_m_21.jpg
# dst sdata\snack\train\gum\gum.48.jpg
# src data\snack\gum\10100_30_m_22.jpg
# dst sdata\snack\train\gum\gum.49.jpg
# src data\snack\gum\10100_30_m_23.jpg
# dst sdata\snack\train\gum\gum.50.jpg
# src data\snack\gum\10100_30_m_24.jpg
# dst sdata\snack\train\gum\gum.51.jpg
# src data\snack\gum\10100_30_m_4.jpg
# dst sdata\snack\train\gum\gum.52.jpg
# src data\snack\gum\10100_30_m_5.jpg
# dst sdata\snack\train\gum\gum.53.jpg
# src data\snack\gum\10100_30_m_6.jpg
# dst sdata\snack\train\gum\gum.54.jpg
# src data\snack\gum\10100_30_m_7.jpg
# dst sdata\snack\train\gum\gum.55.jpg
# src data\snack\gum\10100_30_m_8.jpg
# dst sdata\snack\train\gum\gum.56.jpg
# src data\snack\gum\10100_30_m_9.jpg
# dst sdata\snack\train\gum\gum.57.jpg
# src data\snack\gum\10100_30_s_1.jpg
# dst sdata\snack\train\gum\gum.58.jpg
# src data\snack\gum\10100_30_s_10.jpg
# dst sdata\snack\train\gum\gum.59.jpg
# src data\snack\gum\10100_30_s_11.jpg
# dst sdata\snack\train\gum\gum.60.jpg
# src data\snack\gum\10100_30_s_12.jpg
# dst sdata\snack\train\gum\gum.61.jpg
# src data\snack\gum\10100_30_s_13.jpg
# dst sdata\snack\train\gum\gum.62.jpg
# src data\snack\gum\10100_30_s_14.jpg
# dst sdata\snack\train\gum\gum.63.jpg
# src data\snack\gum\10100_30_s_15.jpg
# dst sdata\snack\train\gum\gum.64.jpg
# src data\snack\gum\10100_30_s_16.jpg
# dst sdata\snack\train\gum\gum.65.jpg
# src data\snack\gum\10100_30_s_17.jpg
# dst sdata\snack\train\gum\gum.66.jpg
# src data\snack\gum\10100_30_s_18.jpg
# dst sdata\snack\valid\gum\gum.67.jpg
# src data\snack\gum\10100_30_s_19.jpg
# dst sdata\snack\valid\gum\gum.68.jpg
# src data\snack\gum\10100_30_s_2.jpg
# dst sdata\snack\valid\gum\gum.69.jpg
# src data\snack\gum\10100_30_s_20.jpg
# dst sdata\snack\valid\gum\gum.70.jpg
# src data\snack\gum\10100_30_s_21.jpg
# dst sdata\snack\valid\gum\gum.71.jpg
# src data\snack\gum\10100_30_s_22.jpg
# dst sdata\snack\valid\gum\gum.72.jpg
# src data\snack\gum\10100_30_s_23.jpg
# dst sdata\snack\valid\gum\gum.73.jpg
# src data\snack\gum\10100_30_s_3.jpg
# dst sdata\snack\valid\gum\gum.74.jpg
# src data\snack\gum\10100_30_s_4.jpg
# dst sdata\snack\valid\gum\gum.75.jpg
# src data\snack\gum\10100_30_s_5.jpg
# dst sdata\snack\valid\gum\gum.76.jpg
# src data\snack\gum\10100_30_s_6.jpg
# dst sdata\snack\valid\gum\gum.77.jpg
# src data\snack\gum\10100_30_s_7.jpg
# dst sdata\snack\valid\gum\gum.78.jpg
# src data\snack\gum\10100_30_s_9.jpg
# dst sdata\snack\valid\gum\gum.79.jpg
# src data\snack\gum\10100_60_m_1.jpg
# dst sdata\snack\valid\gum\gum.80.jpg
# src data\snack\gum\10100_60_m_11.jpg
# dst sdata\snack\valid\gum\gum.81.jpg
# src data\snack\gum\10100_60_m_13.jpg
# dst sdata\snack\valid\gum\gum.82.jpg
# src data\snack\gum\10100_60_m_16.jpg
# dst sdata\snack\valid\gum\gum.83.jpg
# src data\snack\gum\10100_60_m_17.jpg
# dst sdata\snack\valid\gum\gum.84.jpg
# src data\snack\gum\10100_60_m_18.jpg
# dst sdata\snack\valid\gum\gum.85.jpg
# src data\snack\gum\10100_60_m_19.jpg
# dst sdata\snack\valid\gum\gum.86.jpg
# src data\snack\gum\10100_60_m_2.jpg
# dst sdata\snack\valid\gum\gum.87.jpg
# src data\snack\gum\10100_60_m_21.jpg
# dst sdata\snack\test\gum\gum.88.jpg
# src data\snack\gum\10100_60_m_22.jpg
# dst sdata\snack\test\gum\gum.89.jpg
# src data\snack\gum\10100_60_m_23.jpg
# dst sdata\snack\test\gum\gum.90.jpg
# src data\snack\gum\10100_60_m_24.jpg
# dst sdata\snack\test\gum\gum.91.jpg
# src data\snack\gum\10100_60_m_3.jpg
# dst sdata\snack\test\gum\gum.92.jpg
# src data\snack\gum\10100_60_m_5.jpg
# dst sdata\snack\test\gum\gum.93.jpg
# src data\snack\gum\10100_60_m_7.jpg
# dst sdata\snack\test\gum\gum.94.jpg
# src data\snack\gum\10100_60_m_8.jpg
# dst sdata\snack\test\gum\gum.95.jpg
# src data\snack\gum\10100_60_m_9.jpg
# dst sdata\snack\test\gum\gum.96.jpg
# src data\snack\gum\10100_60_s_1.jpg
# dst sdata\snack\test\gum\gum.97.jpg
# src data\snack\gum\10100_60_s_11.jpg
# dst sdata\snack\test\gum\gum.98.jpg
# src data\snack\gum\10100_60_s_12.jpg
# dst sdata\snack\test\gum\gum.99.jpg
# src data\snack\gum\10100_60_s_13.jpg
# dst sdata\snack\test\gum\gum.100.jpg
# src data\snack\gum\10100_60_s_16.jpg
# dst sdata\snack\test\gum\gum.101.jpg
# src data\snack\gum\10100_60_s_17.jpg
# dst sdata\snack\test\gum\gum.102.jpg
# src data\snack\gum\10100_60_s_18.jpg
# dst sdata\snack\test\gum\gum.103.jpg
# src data\snack\gum\10100_60_s_19.jpg
# dst sdata\snack\test\gum\gum.104.jpg
# src data\snack\gum\10100_60_s_21.jpg
# dst sdata\snack\test\gum\gum.105.jpg
# src data\snack\gum\10100_60_s_22.jpg
# dst sdata\snack\test\gum\gum.106.jpg
# src data\snack\gum\10100_60_s_23.jpg
# dst sdata\snack\test\gum\gum.107.jpg
# src data\snack\gum\10100_60_s_24.jpg
# dst sdata\snack\test\gum\gum.108.jpg
# src data\snack\gum\10100_60_s_3.jpg
# dst sdata\snack\test\gum\gum.109.jpg
# src data\snack\gum\10100_60_s_5.jpg
# dst sdata\snack\test\gum\gum.110.jpg
# src data\snack\gum\10100_60_s_6.jpg
# dst sdata\snack\test\gum\gum.111.jpg
# src data\snack\octopus\10092_0_m_10.jpg
# dst sdata\snack\train\octopus\octopus.0.jpg
# src data\snack\octopus\10092_0_m_13.jpg
# dst sdata\snack\train\octopus\octopus.1.jpg
# src data\snack\octopus\10092_0_m_14.jpg
# dst sdata\snack\train\octopus\octopus.2.jpg
# src data\snack\octopus\10092_0_m_15.jpg
# dst sdata\snack\train\octopus\octopus.3.jpg
# src data\snack\octopus\10092_0_m_16.jpg
# dst sdata\snack\train\octopus\octopus.4.jpg
# src data\snack\octopus\10092_0_m_17.jpg
# dst sdata\snack\train\octopus\octopus.5.jpg
# src data\snack\octopus\10092_0_m_18.jpg
# dst sdata\snack\train\octopus\octopus.6.jpg
# src data\snack\octopus\10092_0_m_19.jpg
# dst sdata\snack\train\octopus\octopus.7.jpg
# src data\snack\octopus\10092_0_m_20.jpg
# dst sdata\snack\train\octopus\octopus.8.jpg
# src data\snack\octopus\10092_0_m_22.jpg
# dst sdata\snack\train\octopus\octopus.9.jpg
# src data\snack\octopus\10092_0_m_23.jpg
# dst sdata\snack\train\octopus\octopus.10.jpg
# src data\snack\octopus\10092_0_m_24.jpg
# dst sdata\snack\train\octopus\octopus.11.jpg
# src data\snack\octopus\10092_0_m_3.jpg
# dst sdata\snack\train\octopus\octopus.12.jpg
# src data\snack\octopus\10092_0_m_6.jpg
# dst sdata\snack\train\octopus\octopus.13.jpg
# src data\snack\octopus\10092_0_m_7.jpg
# dst sdata\snack\train\octopus\octopus.14.jpg
# src data\snack\octopus\10092_0_m_8.jpg
# dst sdata\snack\train\octopus\octopus.15.jpg
# src data\snack\octopus\10092_0_m_9.jpg
# dst sdata\snack\train\octopus\octopus.16.jpg
# src data\snack\octopus\10092_0_s_1.jpg
# dst sdata\snack\train\octopus\octopus.17.jpg
# src data\snack\octopus\10092_0_s_10.jpg
# dst sdata\snack\train\octopus\octopus.18.jpg
# src data\snack\octopus\10092_0_s_11.jpg
# dst sdata\snack\train\octopus\octopus.19.jpg
# src data\snack\octopus\10092_0_s_12.jpg
# dst sdata\snack\train\octopus\octopus.20.jpg
# src data\snack\octopus\10092_0_s_13.jpg
# dst sdata\snack\train\octopus\octopus.21.jpg
# src data\snack\octopus\10092_0_s_14.jpg
# dst sdata\snack\train\octopus\octopus.22.jpg
# src data\snack\octopus\10092_0_s_15.jpg
# dst sdata\snack\train\octopus\octopus.23.jpg
# src data\snack\octopus\10092_0_s_18.jpg
# dst sdata\snack\train\octopus\octopus.24.jpg
# src data\snack\octopus\10092_0_s_2.jpg
# dst sdata\snack\train\octopus\octopus.25.jpg
# src data\snack\octopus\10092_0_s_20.jpg
# dst sdata\snack\train\octopus\octopus.26.jpg
# src data\snack\octopus\10092_0_s_21.jpg
# dst sdata\snack\train\octopus\octopus.27.jpg
# src data\snack\octopus\10092_0_s_22.jpg
# dst sdata\snack\train\octopus\octopus.28.jpg
# src data\snack\octopus\10092_0_s_4.jpg
# dst sdata\snack\train\octopus\octopus.29.jpg
# src data\snack\octopus\10092_0_s_5.jpg
# dst sdata\snack\train\octopus\octopus.30.jpg
# src data\snack\octopus\10092_0_s_7.jpg
# dst sdata\snack\train\octopus\octopus.31.jpg
# src data\snack\octopus\10092_0_s_8.jpg
# dst sdata\snack\train\octopus\octopus.32.jpg
# src data\snack\octopus\10092_0_s_9.jpg
# dst sdata\snack\train\octopus\octopus.33.jpg
# src data\snack\octopus\10092_30_m_1.jpg
# dst sdata\snack\train\octopus\octopus.34.jpg
# src data\snack\octopus\10092_30_m_10.jpg
# dst sdata\snack\train\octopus\octopus.35.jpg
# src data\snack\octopus\10092_30_m_11.jpg
# dst sdata\snack\train\octopus\octopus.36.jpg
# src data\snack\octopus\10092_30_m_12.jpg
# dst sdata\snack\train\octopus\octopus.37.jpg
# src data\snack\octopus\10092_30_m_14.jpg
# dst sdata\snack\train\octopus\octopus.38.jpg
# src data\snack\octopus\10092_30_m_15.jpg
# dst sdata\snack\train\octopus\octopus.39.jpg
# src data\snack\octopus\10092_30_m_16.jpg
# dst sdata\snack\train\octopus\octopus.40.jpg
# src data\snack\octopus\10092_30_m_17.jpg
# dst sdata\snack\train\octopus\octopus.41.jpg
# src data\snack\octopus\10092_30_m_18.jpg
# dst sdata\snack\train\octopus\octopus.42.jpg
# src data\snack\octopus\10092_30_m_2.jpg
# dst sdata\snack\train\octopus\octopus.43.jpg
# src data\snack\octopus\10092_30_m_20.jpg
# dst sdata\snack\train\octopus\octopus.44.jpg
# src data\snack\octopus\10092_30_m_21.jpg
# dst sdata\snack\train\octopus\octopus.45.jpg
# src data\snack\octopus\10092_30_m_22.jpg
# dst sdata\snack\train\octopus\octopus.46.jpg
# src data\snack\octopus\10092_30_m_24.jpg
# dst sdata\snack\train\octopus\octopus.47.jpg
# src data\snack\octopus\10092_30_m_4.jpg
# dst sdata\snack\train\octopus\octopus.48.jpg
# src data\snack\octopus\10092_30_m_5.jpg
# dst sdata\snack\train\octopus\octopus.49.jpg
# src data\snack\octopus\10092_30_m_6.jpg
# dst sdata\snack\train\octopus\octopus.50.jpg
# src data\snack\octopus\10092_30_m_8.jpg
# dst sdata\snack\train\octopus\octopus.51.jpg
# src data\snack\octopus\10092_30_m_9.jpg
# dst sdata\snack\train\octopus\octopus.52.jpg
# src data\snack\octopus\10092_30_s_1.jpg
# dst sdata\snack\train\octopus\octopus.53.jpg
# src data\snack\octopus\10092_30_s_10.jpg
# dst sdata\snack\train\octopus\octopus.54.jpg
# src data\snack\octopus\10092_30_s_11.jpg
# dst sdata\snack\train\octopus\octopus.55.jpg
# src data\snack\octopus\10092_30_s_12.jpg
# dst sdata\snack\train\octopus\octopus.56.jpg
# src data\snack\octopus\10092_30_s_13.jpg
# dst sdata\snack\train\octopus\octopus.57.jpg
# src data\snack\octopus\10092_30_s_14.jpg
# dst sdata\snack\train\octopus\octopus.58.jpg
# src data\snack\octopus\10092_30_s_15.jpg
# dst sdata\snack\train\octopus\octopus.59.jpg
# src data\snack\octopus\10092_30_s_16.jpg
# dst sdata\snack\train\octopus\octopus.60.jpg
# src data\snack\octopus\10092_30_s_17.jpg
# dst sdata\snack\train\octopus\octopus.61.jpg
# src data\snack\octopus\10092_30_s_18.jpg
# dst sdata\snack\train\octopus\octopus.62.jpg
# src data\snack\octopus\10092_30_s_19.jpg
# dst sdata\snack\train\octopus\octopus.63.jpg
# src data\snack\octopus\10092_30_s_2.jpg
# dst sdata\snack\train\octopus\octopus.64.jpg
# src data\snack\octopus\10092_30_s_20.jpg
# dst sdata\snack\train\octopus\octopus.65.jpg
# src data\snack\octopus\10092_30_s_21.jpg
# dst sdata\snack\train\octopus\octopus.66.jpg
# src data\snack\octopus\10092_30_s_22.jpg
# dst sdata\snack\valid\octopus\octopus.67.jpg
# src data\snack\octopus\10092_30_s_3.jpg
# dst sdata\snack\valid\octopus\octopus.68.jpg
# src data\snack\octopus\10092_30_s_4.jpg
# dst sdata\snack\valid\octopus\octopus.69.jpg
# src data\snack\octopus\10092_30_s_5.jpg
# dst sdata\snack\valid\octopus\octopus.70.jpg
# src data\snack\octopus\10092_30_s_6.jpg
# dst sdata\snack\valid\octopus\octopus.71.jpg
# src data\snack\octopus\10092_30_s_7.jpg
# dst sdata\snack\valid\octopus\octopus.72.jpg
# src data\snack\octopus\10092_30_s_8.jpg
# dst sdata\snack\valid\octopus\octopus.73.jpg
# src data\snack\octopus\10092_30_s_9.jpg
# dst sdata\snack\valid\octopus\octopus.74.jpg
# src data\snack\octopus\10092_60_m_1.jpg
# dst sdata\snack\valid\octopus\octopus.75.jpg
# src data\snack\octopus\10092_60_m_10.jpg
# dst sdata\snack\valid\octopus\octopus.76.jpg
# src data\snack\octopus\10092_60_m_11.jpg
# dst sdata\snack\valid\octopus\octopus.77.jpg
# src data\snack\octopus\10092_60_m_12.jpg
# dst sdata\snack\valid\octopus\octopus.78.jpg
# src data\snack\octopus\10092_60_m_14.jpg
# dst sdata\snack\valid\octopus\octopus.79.jpg
# src data\snack\octopus\10092_60_m_15.jpg
# dst sdata\snack\valid\octopus\octopus.80.jpg
# src data\snack\octopus\10092_60_m_16.jpg
# dst sdata\snack\valid\octopus\octopus.81.jpg
# src data\snack\octopus\10092_60_m_17.jpg
# dst sdata\snack\valid\octopus\octopus.82.jpg
# src data\snack\octopus\10092_60_m_18.jpg
# dst sdata\snack\valid\octopus\octopus.83.jpg
# src data\snack\octopus\10092_60_m_19.jpg
# dst sdata\snack\valid\octopus\octopus.84.jpg
# src data\snack\octopus\10092_60_m_2.jpg
# dst sdata\snack\valid\octopus\octopus.85.jpg
# src data\snack\octopus\10092_60_m_20.jpg
# dst sdata\snack\valid\octopus\octopus.86.jpg
# src data\snack\octopus\10092_60_m_23.jpg
# dst sdata\snack\valid\octopus\octopus.87.jpg
# src data\snack\octopus\10092_60_m_24.jpg
# dst sdata\snack\test\octopus\octopus.88.jpg
# src data\snack\octopus\10092_60_m_3.jpg
# dst sdata\snack\test\octopus\octopus.89.jpg
# src data\snack\octopus\10092_60_m_4.jpg
# dst sdata\snack\test\octopus\octopus.90.jpg
# src data\snack\octopus\10092_60_m_5.jpg
# dst sdata\snack\test\octopus\octopus.91.jpg
# src data\snack\octopus\10092_60_m_6.jpg
# dst sdata\snack\test\octopus\octopus.92.jpg
# src data\snack\octopus\10092_60_m_7.jpg
# dst sdata\snack\test\octopus\octopus.93.jpg
# src data\snack\octopus\10092_60_m_8.jpg
# dst sdata\snack\test\octopus\octopus.94.jpg
# src data\snack\octopus\10092_60_s_10.jpg
# dst sdata\snack\test\octopus\octopus.95.jpg
# src data\snack\octopus\10092_60_s_13.jpg
# dst sdata\snack\test\octopus\octopus.96.jpg
# src data\snack\octopus\10092_60_s_14.jpg
# dst sdata\snack\test\octopus\octopus.97.jpg
# src data\snack\octopus\10092_60_s_15.jpg
# dst sdata\snack\test\octopus\octopus.98.jpg
# src data\snack\octopus\10092_60_s_17.jpg
# dst sdata\snack\test\octopus\octopus.99.jpg
# src data\snack\octopus\10092_60_s_18.jpg
# dst sdata\snack\test\octopus\octopus.100.jpg
# src data\snack\octopus\10092_60_s_19.jpg
# dst sdata\snack\test\octopus\octopus.101.jpg
# src data\snack\octopus\10092_60_s_2.jpg
# dst sdata\snack\test\octopus\octopus.102.jpg
# src data\snack\octopus\10092_60_s_21.jpg
# dst sdata\snack\test\octopus\octopus.103.jpg
# src data\snack\octopus\10092_60_s_22.jpg
# dst sdata\snack\test\octopus\octopus.104.jpg
# src data\snack\octopus\10092_60_s_23.jpg
# dst sdata\snack\test\octopus\octopus.105.jpg
# src data\snack\octopus\10092_60_s_24.jpg
# dst sdata\snack\test\octopus\octopus.106.jpg
# src data\snack\octopus\10092_60_s_3.jpg
# dst sdata\snack\test\octopus\octopus.107.jpg
# src data\snack\octopus\10092_60_s_4.jpg
# dst sdata\snack\test\octopus\octopus.108.jpg
# src data\snack\octopus\10092_60_s_5.jpg
# dst sdata\snack\test\octopus\octopus.109.jpg
# src data\snack\octopus\10092_60_s_6.jpg
# dst sdata\snack\test\octopus\octopus.110.jpg
# src data\snack\octopus\10092_60_s_7.jpg
# dst sdata\snack\test\octopus\octopus.111.jpg
# src data\snack\shrimp\10093_0_m_1.jpg
# dst sdata\snack\train\shrimp\shrimp.0.jpg
# src data\snack\shrimp\10093_0_m_10.jpg
# dst sdata\snack\train\shrimp\shrimp.1.jpg
# src data\snack\shrimp\10093_0_m_11.jpg
# dst sdata\snack\train\shrimp\shrimp.2.jpg
# src data\snack\shrimp\10093_0_m_12.jpg
# dst sdata\snack\train\shrimp\shrimp.3.jpg
# src data\snack\shrimp\10093_0_m_14.jpg
# dst sdata\snack\train\shrimp\shrimp.4.jpg
# src data\snack\shrimp\10093_0_m_15.jpg
# dst sdata\snack\train\shrimp\shrimp.5.jpg
# src data\snack\shrimp\10093_0_m_17.jpg
# dst sdata\snack\train\shrimp\shrimp.6.jpg
# src data\snack\shrimp\10093_0_m_18.jpg
# dst sdata\snack\train\shrimp\shrimp.7.jpg
# src data\snack\shrimp\10093_0_m_19.jpg
# dst sdata\snack\train\shrimp\shrimp.8.jpg
# src data\snack\shrimp\10093_0_m_2.jpg
# dst sdata\snack\train\shrimp\shrimp.9.jpg
# src data\snack\shrimp\10093_0_m_21.jpg
# dst sdata\snack\train\shrimp\shrimp.10.jpg
# src data\snack\shrimp\10093_0_m_22.jpg
# dst sdata\snack\train\shrimp\shrimp.11.jpg
# src data\snack\shrimp\10093_0_m_24.jpg
# dst sdata\snack\train\shrimp\shrimp.12.jpg
# src data\snack\shrimp\10093_0_m_3.jpg
# dst sdata\snack\train\shrimp\shrimp.13.jpg
# src data\snack\shrimp\10093_0_m_4.jpg
# dst sdata\snack\train\shrimp\shrimp.14.jpg
# src data\snack\shrimp\10093_0_m_5.jpg
# dst sdata\snack\train\shrimp\shrimp.15.jpg
# src data\snack\shrimp\10093_0_m_7.jpg
# dst sdata\snack\train\shrimp\shrimp.16.jpg
# src data\snack\shrimp\10093_0_m_8.jpg
# dst sdata\snack\train\shrimp\shrimp.17.jpg
# src data\snack\shrimp\10093_0_m_9.jpg
# dst sdata\snack\train\shrimp\shrimp.18.jpg
# src data\snack\shrimp\10093_0_s_10.jpg
# dst sdata\snack\train\shrimp\shrimp.19.jpg
# src data\snack\shrimp\10093_0_s_11.jpg
# dst sdata\snack\train\shrimp\shrimp.20.jpg
# src data\snack\shrimp\10093_0_s_12.jpg
# dst sdata\snack\train\shrimp\shrimp.21.jpg
# src data\snack\shrimp\10093_0_s_13.jpg
# dst sdata\snack\train\shrimp\shrimp.22.jpg
# src data\snack\shrimp\10093_0_s_14.jpg
# dst sdata\snack\train\shrimp\shrimp.23.jpg
# src data\snack\shrimp\10093_0_s_16.jpg
# dst sdata\snack\train\shrimp\shrimp.24.jpg
# src data\snack\shrimp\10093_0_s_17.jpg
# dst sdata\snack\train\shrimp\shrimp.25.jpg
# src data\snack\shrimp\10093_0_s_18.jpg
# dst sdata\snack\train\shrimp\shrimp.26.jpg
# src data\snack\shrimp\10093_0_s_19.jpg
# dst sdata\snack\train\shrimp\shrimp.27.jpg
# src data\snack\shrimp\10093_0_s_2.jpg
# dst sdata\snack\train\shrimp\shrimp.28.jpg
# src data\snack\shrimp\10093_0_s_20.jpg
# dst sdata\snack\train\shrimp\shrimp.29.jpg
# src data\snack\shrimp\10093_0_s_21.jpg
# dst sdata\snack\train\shrimp\shrimp.30.jpg
# src data\snack\shrimp\10093_0_s_22.jpg
# dst sdata\snack\train\shrimp\shrimp.31.jpg
# src data\snack\shrimp\10093_0_s_23.jpg
# dst sdata\snack\train\shrimp\shrimp.32.jpg
# src data\snack\shrimp\10093_0_s_24.jpg
# dst sdata\snack\train\shrimp\shrimp.33.jpg
# src data\snack\shrimp\10093_0_s_3.jpg
# dst sdata\snack\train\shrimp\shrimp.34.jpg
# src data\snack\shrimp\10093_0_s_5.jpg
# dst sdata\snack\train\shrimp\shrimp.35.jpg
# src data\snack\shrimp\10093_0_s_6.jpg
# dst sdata\snack\train\shrimp\shrimp.36.jpg
# src data\snack\shrimp\10093_0_s_7.jpg
# dst sdata\snack\train\shrimp\shrimp.37.jpg
# src data\snack\shrimp\10093_0_s_8.jpg
# dst sdata\snack\train\shrimp\shrimp.38.jpg
# src data\snack\shrimp\10093_0_s_9.jpg
# dst sdata\snack\train\shrimp\shrimp.39.jpg
# src data\snack\shrimp\10093_30_m_12.jpg
# dst sdata\snack\train\shrimp\shrimp.40.jpg
# src data\snack\shrimp\10093_30_m_14.jpg
# dst sdata\snack\train\shrimp\shrimp.41.jpg
# src data\snack\shrimp\10093_30_m_15.jpg
# dst sdata\snack\train\shrimp\shrimp.42.jpg
# src data\snack\shrimp\10093_30_m_16.jpg
# dst sdata\snack\train\shrimp\shrimp.43.jpg
# src data\snack\shrimp\10093_30_m_19.jpg
# dst sdata\snack\train\shrimp\shrimp.44.jpg
# src data\snack\shrimp\10093_30_m_2.jpg
# dst sdata\snack\train\shrimp\shrimp.45.jpg
# src data\snack\shrimp\10093_30_m_20.jpg
# dst sdata\snack\train\shrimp\shrimp.46.jpg
# src data\snack\shrimp\10093_30_m_21.jpg
# dst sdata\snack\train\shrimp\shrimp.47.jpg
# src data\snack\shrimp\10093_30_m_22.jpg
# dst sdata\snack\train\shrimp\shrimp.48.jpg
# src data\snack\shrimp\10093_30_m_23.jpg
# dst sdata\snack\train\shrimp\shrimp.49.jpg
# src data\snack\shrimp\10093_30_m_24.jpg
# dst sdata\snack\train\shrimp\shrimp.50.jpg
# src data\snack\shrimp\10093_30_m_3.jpg
# dst sdata\snack\train\shrimp\shrimp.51.jpg
# src data\snack\shrimp\10093_30_m_4.jpg
# dst sdata\snack\train\shrimp\shrimp.52.jpg
# src data\snack\shrimp\10093_30_m_6.jpg
# dst sdata\snack\train\shrimp\shrimp.53.jpg
# src data\snack\shrimp\10093_30_m_7.jpg
# dst sdata\snack\train\shrimp\shrimp.54.jpg
# src data\snack\shrimp\10093_30_m_8.jpg
# dst sdata\snack\train\shrimp\shrimp.55.jpg
# src data\snack\shrimp\10093_30_s_1.jpg
# dst sdata\snack\train\shrimp\shrimp.56.jpg
# src data\snack\shrimp\10093_30_s_10.jpg
# dst sdata\snack\train\shrimp\shrimp.57.jpg
# src data\snack\shrimp\10093_30_s_11.jpg
# dst sdata\snack\train\shrimp\shrimp.58.jpg
# src data\snack\shrimp\10093_30_s_12.jpg
# dst sdata\snack\train\shrimp\shrimp.59.jpg
# src data\snack\shrimp\10093_30_s_13.jpg
# dst sdata\snack\train\shrimp\shrimp.60.jpg
# src data\snack\shrimp\10093_30_s_14.jpg
# dst sdata\snack\train\shrimp\shrimp.61.jpg
# src data\snack\shrimp\10093_30_s_15.jpg
# dst sdata\snack\train\shrimp\shrimp.62.jpg
# src data\snack\shrimp\10093_30_s_16.jpg
# dst sdata\snack\train\shrimp\shrimp.63.jpg
# src data\snack\shrimp\10093_30_s_18.jpg
# dst sdata\snack\train\shrimp\shrimp.64.jpg
# src data\snack\shrimp\10093_30_s_19.jpg
# dst sdata\snack\train\shrimp\shrimp.65.jpg
# src data\snack\shrimp\10093_30_s_2.jpg
# dst sdata\snack\train\shrimp\shrimp.66.jpg
# src data\snack\shrimp\10093_30_s_20.jpg
# dst sdata\snack\valid\shrimp\shrimp.67.jpg
# src data\snack\shrimp\10093_30_s_21.jpg
# dst sdata\snack\valid\shrimp\shrimp.68.jpg
# src data\snack\shrimp\10093_30_s_22.jpg
# dst sdata\snack\valid\shrimp\shrimp.69.jpg
# src data\snack\shrimp\10093_30_s_23.jpg
# dst sdata\snack\valid\shrimp\shrimp.70.jpg
# src data\snack\shrimp\10093_30_s_24.jpg
# dst sdata\snack\valid\shrimp\shrimp.71.jpg
# src data\snack\shrimp\10093_30_s_4.jpg
# dst sdata\snack\valid\shrimp\shrimp.72.jpg
# src data\snack\shrimp\10093_30_s_5.jpg
# dst sdata\snack\valid\shrimp\shrimp.73.jpg
# src data\snack\shrimp\10093_30_s_6.jpg
# dst sdata\snack\valid\shrimp\shrimp.74.jpg
# src data\snack\shrimp\10093_30_s_7.jpg
# dst sdata\snack\valid\shrimp\shrimp.75.jpg
# src data\snack\shrimp\10093_30_s_9.jpg
# dst sdata\snack\valid\shrimp\shrimp.76.jpg
# src data\snack\shrimp\10093_60_m_1.jpg
# dst sdata\snack\valid\shrimp\shrimp.77.jpg
# src data\snack\shrimp\10093_60_m_10.jpg
# dst sdata\snack\valid\shrimp\shrimp.78.jpg
# src data\snack\shrimp\10093_60_m_12.jpg
# dst sdata\snack\valid\shrimp\shrimp.79.jpg
# src data\snack\shrimp\10093_60_m_13.jpg
# dst sdata\snack\valid\shrimp\shrimp.80.jpg
# src data\snack\shrimp\10093_60_m_14.jpg
# dst sdata\snack\valid\shrimp\shrimp.81.jpg
# src data\snack\shrimp\10093_60_m_15.jpg
# dst sdata\snack\valid\shrimp\shrimp.82.jpg
# src data\snack\shrimp\10093_60_m_16.jpg
# dst sdata\snack\valid\shrimp\shrimp.83.jpg
# src data\snack\shrimp\10093_60_m_17.jpg
# dst sdata\snack\valid\shrimp\shrimp.84.jpg
# src data\snack\shrimp\10093_60_m_18.jpg
# dst sdata\snack\valid\shrimp\shrimp.85.jpg
# src data\snack\shrimp\10093_60_m_2.jpg
# dst sdata\snack\valid\shrimp\shrimp.86.jpg
# src data\snack\shrimp\10093_60_m_20.jpg
# dst sdata\snack\valid\shrimp\shrimp.87.jpg
# src data\snack\shrimp\10093_60_m_21.jpg
# dst sdata\snack\test\shrimp\shrimp.88.jpg
# src data\snack\shrimp\10093_60_m_22.jpg
# dst sdata\snack\test\shrimp\shrimp.89.jpg
# src data\snack\shrimp\10093_60_m_23.jpg
# dst sdata\snack\test\shrimp\shrimp.90.jpg
# src data\snack\shrimp\10093_60_m_24.jpg
# dst sdata\snack\test\shrimp\shrimp.91.jpg
# src data\snack\shrimp\10093_60_m_4.jpg
# dst sdata\snack\test\shrimp\shrimp.92.jpg
# src data\snack\shrimp\10093_60_m_6.jpg
# dst sdata\snack\test\shrimp\shrimp.93.jpg
# src data\snack\shrimp\10093_60_m_7.jpg
# dst sdata\snack\test\shrimp\shrimp.94.jpg
# src data\snack\shrimp\10093_60_m_8.jpg
# dst sdata\snack\test\shrimp\shrimp.95.jpg
# src data\snack\shrimp\10093_60_m_9.jpg
# dst sdata\snack\test\shrimp\shrimp.96.jpg
# src data\snack\shrimp\10093_60_s_1.jpg
# dst sdata\snack\test\shrimp\shrimp.97.jpg
# src data\snack\shrimp\10093_60_s_10.jpg
# dst sdata\snack\test\shrimp\shrimp.98.jpg
# src data\snack\shrimp\10093_60_s_11.jpg
# dst sdata\snack\test\shrimp\shrimp.99.jpg
# src data\snack\shrimp\10093_60_s_13.jpg
# dst sdata\snack\test\shrimp\shrimp.100.jpg
# src data\snack\shrimp\10093_60_s_15.jpg
# dst sdata\snack\test\shrimp\shrimp.101.jpg
# src data\snack\shrimp\10093_60_s_16.jpg
# dst sdata\snack\test\shrimp\shrimp.102.jpg
# src data\snack\shrimp\10093_60_s_17.jpg
# dst sdata\snack\test\shrimp\shrimp.103.jpg
# src data\snack\shrimp\10093_60_s_18.jpg
# dst sdata\snack\test\shrimp\shrimp.104.jpg
# src data\snack\shrimp\10093_60_s_2.jpg
# dst sdata\snack\test\shrimp\shrimp.105.jpg
# src data\snack\shrimp\10093_60_s_20.jpg
# dst sdata\snack\test\shrimp\shrimp.106.jpg
# src data\snack\shrimp\10093_60_s_21.jpg
# dst sdata\snack\test\shrimp\shrimp.107.jpg
# src data\snack\shrimp\10093_60_s_22.jpg
# dst sdata\snack\test\shrimp\shrimp.108.jpg
# src data\snack\shrimp\10093_60_s_24.jpg
# dst sdata\snack\test\shrimp\shrimp.109.jpg
# src data\snack\shrimp\10093_60_s_3.jpg
# dst sdata\snack\test\shrimp\shrimp.110.jpg
# src data\snack\shrimp\10093_60_s_5.jpg
# dst sdata\snack\test\shrimp\shrimp.111.jpg
# 데이터셋 분할 및 복사가 완료되었습니다.

# %%
dirList = [train_sdata_banana, train_sdata_blueberry, train_sdata_choco, train_sdata_cone, train_sdata_gum, train_sdata_octopus, train_sdata_shrimp,
           valid_sdata_banana, valid_sdata_blueberry, valid_sdata_choco, valid_sdata_cone, valid_sdata_gum, valid_sdata_octopus, valid_sdata_shrimp,
           test_sdata_banana, test_sdata_blueberry, test_sdata_choco, test_sdata_cone, test_sdata_gum, test_sdata_octopus, test_sdata_shrimp]

for dir in dirList:
    print(len(os.listdir(dir)))
# Out:
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 24
# 24
# 24
# 24
# 24
# 24
# 24

# %%
# 위에서 복사된 파일들 갯수 확인하기
train_banana = os.listdir(os.path.join(train_dir,'banana'))
train_blueberry = os.listdir(os.path.join(train_dir,'blueberry'))
train_choco = os.listdir(os.path.join(train_dir,'choco'))
train_cone = os.listdir(os.path.join(train_dir,'cone'))
train_gum = os.listdir(os.path.join(train_dir,'gum'))
train_octopus = os.listdir(os.path.join(train_dir,'octopus'))
train_shrimp = os.listdir(os.path.join(train_dir,'shrimp'))

valid_banana = os.listdir(os.path.join(test_dir,'banana'))
valid_blueberry = os.listdir(os.path.join(test_dir,'blueberry'))
valid_choco = os.listdir(os.path.join(test_dir,'choco'))
valid_cone = os.listdir(os.path.join(test_dir,'cone'))
valid_gum = os.listdir(os.path.join(test_dir,'gum'))
valid_octopus = os.listdir(os.path.join(test_dir,'octopus'))
valid_shrimp = os.listdir(os.path.join(test_dir,'shrimp'))

test_banana = os.listdir(os.path.join(test_dir,'banana'))
test_blueberry = os.listdir(os.path.join(test_dir,'blueberry'))
test_choco = os.listdir(os.path.join(test_dir,'choco'))
test_cone = os.listdir(os.path.join(test_dir,'cone'))
test_gum = os.listdir(os.path.join(test_dir,'gum'))
test_octopus = os.listdir(os.path.join(test_dir,'octopus'))
test_shrimp = os.listdir(os.path.join(test_dir,'shrimp'))

#위의 6개 폴더 파일 갯수 확인하기
print(len(train_banana),len(train_blueberry), len(train_choco),len(train_cone), len(train_gum),len(train_octopus), len(train_shrimp),
      len(valid_banana),len(valid_blueberry), len(valid_choco),len(valid_cone), len(valid_gum),len(valid_octopus), len(valid_shrimp),
      len(test_banana),len(test_blueberry), len(test_choco),len(test_cone), len(test_gum),len(test_octopus), len(test_shrimp))
# Out:
# 67 67 67 67 67 67 67 24 24 24 24 24 24 24 24 24 24 24 24 24 24

# %%
import cv2
img = cv2.imread(os.path.join(os.path.join(train_dir,'banana',train_banana[3])))
img
# Out:
# array([[[194, 196, 196],
#         [194, 196, 196],
#         [194, 196, 196],
#         ...,
#         [201, 206, 205],
#         [201, 206, 205],
#         [201, 206, 205]],
#
#        [[196, 198, 198],
#         [195, 197, 197],
#         [194, 196, 196],
#         ...,
#         [199, 204, 203],
#         [199, 204, 203],
#         [199, 204, 203]],
#
#        [[197, 199, 199],
#         [196, 198, 198],
#         [195, 197, 197],
#         ...,
#         [198, 203, 202],
#         [198, 203, 202],
#         [198, 203, 202]],
#
#        ...,
#
#        [[215, 210, 207],
#         [215, 210, 207],
#         [214, 209, 206],
#         ...,
#         [223, 218, 215],
#         [223, 218, 215],
#         [223, 218, 215]],
#
#        [[214, 209, 206],
#         [214, 209, 206],
#         [214, 209, 206],
#         ...,
#         [222, 217, 214],
#         [222, 217, 214],
#         [222, 217, 214]],
#
#        [[214, 209, 206],
#         [214, 209, 206],
#         [214, 209, 206],
#         ...,
#         [223, 218, 215],
#         [223, 218, 215],
#         [223, 218, 215]]], dtype=uint8)

# %%
from torchvision import transforms

org_size =(256,256)
org_size =(224,224)
img_size = 224

visual_transform = transforms.Compose([
    transforms.Resize(org_size),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(img_size),
    # 평균이 0.5 표준편차 0.5 (0~1사이의 실수)
    transforms.ToTensor(),
    ])

train_transform = transforms.RandomOrder([
    #이미지 사이즈가 파일마다 제 각각
    transforms.RandomRotation(180),
    transforms.RandomAffine(180, shear=20),
    transforms.RandomPerspective(fill=[255,0,255])
    transforms.RandomErasing()
    transforms.RandomInvert()
    transforms.RandomPosterize(1.5)
    transforms.RandomSolarize(200.5)
    transforms.RandomAdjustSharpness
    transforms.RandomAutocontrast()
    transforms.RandomEqualize()
    transforms.AutoAugment(transforms.AutoAugmentPolicy.IMAGENET)
    transforms.Resize(org_size),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(img_size),
    # 평균이 0.5 표준편차 0.5 (0~1사이의 실수)
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ])

test_transform = transforms.Compose([
    transforms.Resize(org_size),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ])

# %%
from torchvision.datasets import ImageFolder
from torchvision import transforms
import os

# Custom ImageFolder to return file name along with image and label
class ImageFolderWithFilenames(ImageFolder):
    def __getitem__(self, index):
        # Get the original tuple (image, label)
        original_tuple = super(ImageFolderWithFilenames, self).__getitem__(index)

        # Get the image file path
        path, _ = self.samples[index]
        # Return the image, label, and the file name (path)
        return original_tuple + (path,)

# %%
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

data_dir = os.getcwd() + '/sdata/snack'

batch_size = 32

visual_data = ImageFolder(root=f"{data_dir}/train", transform=visual_transform)
train_data = ImageFolder(root=f"{data_dir}/train", transform=train_transform)
valid_data = ImageFolder(root=f"{data_dir}/valid", transform=test_transform)
test_data = ImageFolderWithFilenames(root=f"{data_dir}/test", transform=test_transform)

visual_loader = DataLoader(visual_data, batch_size=batch_size, shuffle=True)
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=1, shuffle=False)

# %%
import matplotlib.pyplot as plt

# train데이터가 2000장이 있는데, 32장씩 데이터를 가져온다.
images, labels = next(iter(visual_loader))

classes ={0:'banana', 1:'blueberry', 2:'choco', 3:'cone', 4:'gum', 5:'octopus', 6:'shrimp'}

fig = plt.figure(figsize=(14, 8))
for i in range(batch_size):
    # 4행 8열
    ax = fig.add_subplot(4, 8, i + 1)
    ax.set_title(classes[labels[i].item()])
    ax.axis('off')
    # 컬러 채널 순서를 재정렬
    ax.imshow(images[i].permute(1, 2, 0))

plt.show()

# %%
import torch
from torchvision.models import resnet50, mobilenet_v3_large

isResnet50 = True

device='cuda' if torch.cuda.is_available() else 'cpu'

# ImageNet에 사전학습된 모델을 가져와서 학습(Train)
# 분류기는 제외하고 특징 추출기만 사용

if isResnet50:
    model = resnet50(pretrained=True).to(device)
else:
    model = mobilenet_v3_large(pretrained=True).to(device)

model
# Out:
# C:\Users\sba\miniconda3\envs\pytorch\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\sba\miniconda3\envs\pytorch\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
model = resnet50(pretrained=True).to(device)

# 특징 추출기는 그대로 사용하고, 분류기만 2개짜리로 변경
# fc -> 분류기 in_features -> 분류기의 입력
num_features = model.fc.in_features

# num_classes: 분류해야 할 클래스 수 (예: 3개의 클래스)
num_classes = 7

# 분류기 부분을 Softmax 활성화 함수로 변경
model.fc = torch.nn.Sequential(
    torch.nn.Linear(num_features, 256),  # 입력에서 256개의 노드로 연결
    torch.nn.ReLU(),                     # 활성화 함수 ReLU
    torch.nn.Linear(256, num_classes)    # 최종 분류 클래스의 수에 맞게 출력 노드 수 설정
).to(device)

model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=7, bias=True)
#   )
# )

# %%
import time
from tqdm import tqdm

# 학습 진행
def fit(model, criterion, optimizer, epochs, train_loader, valid_loader, resume=False):

    if resume==False:
        # 그래프로 출력하기 위한 리스트
        train_losses = []
        train_accuracies = []
        valid_losses = []
        valid_accuracies = []

    for epoch in range(epochs):
        start = time.time()

        # 훈련 모드
        model.train()

        train_loss = 0
        train_acc = 0
        train_correct = 0

        for train_x, train_y in tqdm(train_loader):
            train_x, train_y = train_x.to(device), train_y.to(device)
            optimizer.zero_grad()
            outputs = model(train_x)

            # softmax + loss
            loss = criterion(outputs, train_y)

            loss.backward()
            optimizer.step()

            # batch마다 train_loss를 누적
            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            train_correct += (predicted == train_y).sum().item()

        valid_loss = 0
        valid_acc = 0
        valid_correct = 0

        for valid_x, valid_y in valid_loader:
            with torch.no_grad():
                model.eval()
                valid_x, valid_y = valid_x.to(device), valid_y.to(device)
                outputs = model(valid_x)
                loss = criterion(outputs, valid_y)
                valid_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                valid_correct += (predicted == valid_y).sum().item()

        train_acc = train_correct/len(train_loader.dataset)
        valid_acc = valid_correct/len(valid_loader.dataset)

        print(f'{time.time() - start:.3f}sec : [Epoch {epoch+1}/{epochs}] -> train loss: {train_loss/len(train_loader):.4f}, train acc: {train_acc*100:.3f}% / valid loss: {valid_loss/len(valid_loader):.4f}, valid acc: {valid_acc*100:.3f}%')

        train_losses.append(train_loss/len(train_loader))
        train_accuracies.append(train_acc)
        valid_losses.append(valid_loss/len(valid_loader))
        valid_accuracies.append(valid_acc)

        scheduler.step(valid_loss)
        # 현재 learning_rate 값을 읽어올 수 있다.
        now_lr = optimizer.param_groups[0]['lr']
        print(f'learning_rate {epoch+1}: {now_lr:.8f}')

        # EarlyStopping을 호출하여 학습 중단 여부 확인
        early_stopping(valid_loss, model)

        # 학습 중단 조건을 충족하면 break
        if early_stopping.early_stop:
            print("Early stopping triggered.")
            break
        print('-' * 100)

    plt.plot(train_losses, label='loss')
    plt.plot(train_accuracies, label='accuracy')
    plt.legend()
    plt.title('train loss and accuracy')
    plt.show()

    plt.plot(valid_losses, label='loss')
    plt.plot(valid_accuracies, label='accuracy')
    plt.legend()
    plt.title('valid loss and accuracy')
    plt.show()

# %%
# EarlyStopping 클래스
class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt'):
        """
        Args:
            patience (int): 성능 개선이 없을 때 몇 번의 에포크까지 기다릴지.
            verbose (bool): True일 경우 개선될 때마다 메시지 출력.
            delta (float): 성능 개선으로 간주될 최소 변화량.
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        score = -val_loss
        # 처음에 호출됐을때는 best_score가 None이라서 초기값을 설정
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        # 지금까지의 best_score와 현재 score를 비교
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            # patience값이 모두 충족했을때, 종료조건이 만족될때
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''검증 손실이 감소하면 모델을 저장합니다.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
            torch.save(model.state_dict(), self.path)  # 모델 상태 저장
        self.val_loss_min = val_loss

# EarlyStopping 인스턴스 생성 (patience=10)
early_stopping = EarlyStopping(patience=10, verbose=True, path='resnet50_best.pth')

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau

LR = 0.00001
EPOCHS = 25
# 손실함수
# 신경망에 sigmoid를 썼으므로 BCELoss()사용
# 만약 신경망에 softmax를 썼다면 CrossEntropyLoss()사용
criterion = torch.nn.CrossEntropyLoss().to(device)
# optimizer정의
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

# scheduler 추가
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

# 학습
fit(model, criterion, optimizer, EPOCHS, train_loader, valid_loader, resume=False)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:45<00:00,  3.03s/it]
# 57.906sec : [Epoch 1/25] -> train loss: 1.8637, train acc: 32.836% / valid loss: 1.8033, valid acc: 53.061%
# learning_rate 1: 0.00001000
# Validation loss decreased (inf --> 9.016421).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:42<00:00,  2.83s/it]
# 54.376sec : [Epoch 2/25] -> train loss: 1.6437, train acc: 78.252% / valid loss: 1.6250, valid acc: 69.388%
# learning_rate 2: 0.00001000
# Validation loss decreased (9.016421 --> 8.124955).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.76s/it]
# 53.089sec : [Epoch 3/25] -> train loss: 1.4052, train acc: 96.802% / valid loss: 1.4143, valid acc: 87.755%
# learning_rate 3: 0.00001000
# Validation loss decreased (8.124955 --> 7.071369).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.78s/it]
# 53.384sec : [Epoch 4/25] -> train loss: 1.1596, train acc: 99.360% / valid loss: 1.1874, valid acc: 95.918%
# learning_rate 4: 0.00001000
# Validation loss decreased (7.071369 --> 5.936827).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.75s/it]
# 52.949sec : [Epoch 5/25] -> train loss: 0.8940, train acc: 100.000% / valid loss: 0.9563, valid acc: 97.959%
# learning_rate 5: 0.00001000
# Validation loss decreased (5.936827 --> 4.781549).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.75s/it]
# 52.778sec : [Epoch 6/25] -> train loss: 0.6654, train acc: 100.000% / valid loss: 0.7503, valid acc: 99.320%
# learning_rate 6: 0.00001000
# Validation loss decreased (4.781549 --> 3.751736).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.73s/it]
# 52.735sec : [Epoch 7/25] -> train loss: 0.4594, train acc: 99.787% / valid loss: 0.5742, valid acc: 100.000%
# learning_rate 7: 0.00001000
# Validation loss decreased (3.751736 --> 2.871248).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.75s/it]
# 52.993sec : [Epoch 8/25] -> train loss: 0.3259, train acc: 100.000% / valid loss: 0.4516, valid acc: 100.000%
# learning_rate 8: 0.00001000
# Validation loss decreased (2.871248 --> 2.257991).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.75s/it]
# 53.137sec : [Epoch 9/25] -> train loss: 0.2251, train acc: 100.000% / valid loss: 0.3650, valid acc: 100.000%
# learning_rate 9: 0.00001000
# Validation loss decreased (2.257991 --> 1.825085).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.74s/it]
# 52.846sec : [Epoch 10/25] -> train loss: 0.1700, train acc: 100.000% / valid loss: 0.2992, valid acc: 100.000%
# learning_rate 10: 0.00001000
# Validation loss decreased (1.825085 --> 1.495765).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:42<00:00,  2.80s/it]
# 53.994sec : [Epoch 11/25] -> train loss: 0.1277, train acc: 100.000% / valid loss: 0.2570, valid acc: 100.000%
# learning_rate 11: 0.00001000
# Validation loss decreased (1.495765 --> 1.284936).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.75s/it]
# 53.172sec : [Epoch 12/25] -> train loss: 0.1044, train acc: 100.000% / valid loss: 0.2237, valid acc: 100.000%
# learning_rate 12: 0.00001000
# Validation loss decreased (1.284936 --> 1.118690).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:42<00:00,  2.82s/it]
# 54.150sec : [Epoch 13/25] -> train loss: 0.0883, train acc: 100.000% / valid loss: 0.2014, valid acc: 100.000%
# learning_rate 13: 0.00001000
# Validation loss decreased (1.118690 --> 1.007095).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.75s/it]
# 53.235sec : [Epoch 14/25] -> train loss: 0.0705, train acc: 100.000% / valid loss: 0.1714, valid acc: 100.000%
# learning_rate 14: 0.00001000
# Validation loss decreased (1.007095 --> 0.857062).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.76s/it]
# 53.155sec : [Epoch 15/25] -> train loss: 0.0553, train acc: 100.000% / valid loss: 0.1705, valid acc: 100.000%
# learning_rate 15: 0.00001000
# Validation loss decreased (0.857062 --> 0.852504).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.74s/it]
# 52.983sec : [Epoch 16/25] -> train loss: 0.0663, train acc: 99.787% / valid loss: 0.1388, valid acc: 100.000%
# learning_rate 16: 0.00001000
# Validation loss decreased (0.852504 --> 0.694211).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.75s/it]
# 53.141sec : [Epoch 17/25] -> train loss: 0.0482, train acc: 100.000% / valid loss: 0.1321, valid acc: 100.000%
# learning_rate 17: 0.00001000
# Validation loss decreased (0.694211 --> 0.660690).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.78s/it]
# 53.606sec : [Epoch 18/25] -> train loss: 0.0372, train acc: 100.000% / valid loss: 0.1253, valid acc: 100.000%
# learning_rate 18: 0.00001000
# Validation loss decreased (0.660690 --> 0.626733).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.75s/it]
# 53.724sec : [Epoch 19/25] -> train loss: 0.0344, train acc: 100.000% / valid loss: 0.1189, valid acc: 100.000%
# learning_rate 19: 0.00001000
# Validation loss decreased (0.626733 --> 0.594445).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.76s/it]
# 53.249sec : [Epoch 20/25] -> train loss: 0.0316, train acc: 100.000% / valid loss: 0.1079, valid acc: 100.000%
# learning_rate 20: 0.00001000
# Validation loss decreased (0.594445 --> 0.539391).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.76s/it]
# 53.177sec : [Epoch 21/25] -> train loss: 0.0272, train acc: 100.000% / valid loss: 0.1080, valid acc: 100.000%
# learning_rate 21: 0.00001000
# EarlyStopping counter: 1 out of 10
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:42<00:00,  2.81s/it]
# 53.791sec : [Epoch 22/25] -> train loss: 0.0279, train acc: 100.000% / valid loss: 0.0968, valid acc: 100.000%
# learning_rate 22: 0.00001000
# Validation loss decreased (0.539391 --> 0.484143).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.75s/it]
# 52.901sec : [Epoch 23/25] -> train loss: 0.0234, train acc: 100.000% / valid loss: 0.0870, valid acc: 100.000%
# learning_rate 23: 0.00001000
# Validation loss decreased (0.484143 --> 0.435237).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:40<00:00,  2.73s/it]
# 52.314sec : [Epoch 24/25] -> train loss: 0.0221, train acc: 100.000% / valid loss: 0.0837, valid acc: 100.000%
# learning_rate 24: 0.00001000
# Validation loss decreased (0.435237 --> 0.418716).  Saving model ...
# ----------------------------------------------------------------------------------------------------
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:41<00:00,  2.75s/it]
# 52.845sec : [Epoch 25/25] -> train loss: 0.0221, train acc: 100.000% / valid loss: 0.0817, valid acc: 100.000%
# learning_rate 25: 0.00001000
# Validation loss decreased (0.418716 --> 0.408376).  Saving model ...
# ----------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
from PIL import Image

# 테스트 데이터에서 성능을 평가하고, 예측이 잘못된 이미지를 시각화하는 함수
def evaluate_and_visualize(model, test_loader, criterion):
    test_loss = 0
    test_correct = 0
    test_total = 0
    #incorrect_images = []
    incorrect_labels = []
    incorrect_preds = []
    incorrect_filenames = []

    model.eval()
    with torch.no_grad():
        for test_x, test_y, filenames in tqdm(test_loader):
            test_x, test_y = test_x.to(device), test_y.to(device)
            outputs = model(test_x)
            loss = criterion(outputs, test_y)
            test_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)

            # 정확도 계산
            test_correct += (predicted == test_y).sum().item()
            test_total += test_y.size(0)

            if predicted != test_y:
                incorrect_labels.append(test_y.cpu().numpy())
                incorrect_preds.append(predicted.cpu().numpy())
                incorrect_filenames.append(filenames[0])

    test_accuracy = test_correct / test_total
    print("test_correct:{}, test_total:{}".format(test_correct, test_total))
    print(f'Test Loss: {test_loss / len(test_loader):.4f}, Test Accuracy: {test_accuracy * 100:.2f}%')

    print(len(incorrect_filenames))

    # 예측이 잘못된 이미지 시각화
    fig = plt.figure(figsize=(12, 12))
    for i in range(min(16, len(incorrect_filenames))):
        ax = fig.add_subplot(4, 4, i + 1)
        image = Image.open(incorrect_filenames[i])
        ax.imshow(image)
        label_dict = {0:'banana', 1:'blueberry', 2:'choco', 3:'cone', 4:'gum', 5:'octopus', 6:'shrimp'}
        true_label = label_dict[incorrect_labels[i]]
        pred_label = label_dict[incorrect_preds[i]]
        # true_label = label_dict[] if incorrect_labels[i] == 1 else 'blueberry'
        # pred_label = label_dict[] if incorrect_preds[i] == 1 else 'blueberry'
        filename = os.path.basename(incorrect_filenames[i])
        ax.set_title(f'Pred: {pred_label}, Label: {true_label}, {filename}', fontsize=10)
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# %%
# 테스트 데이터를 통해 성능 평가 및 잘못된 예측 시각화
evaluate_and_visualize(model, test_loader, criterion)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 168/168 [00:17<00:00,  9.85it/s]
# test_correct:168, test_total:168
# Test Loss: 0.1770, Test Accuracy: 100.00%
# 0

# %%
import torch
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
import os

# Function to classify and display an image
def classify_and_show_image(model, image_path, device='cpu'):
    # Assuming the model is already loaded and `label_dict` contains the mapping of class indices to labels
    label_dict = {0: 'banana', 1: 'blueberry', 2: 'choco', 3: 'cone', 4: 'gum', 5: 'octopus', 6: 'shrimp'}
    # Load the image
    image = Image.open(image_path)
    
    # Define preprocessing transformations (these should match the ones used during training)
    transform = transforms.Compose([
        transforms.Resize((224, 224)),  # Resize to the input size expected by the model
        transforms.ToTensor(),  # Convert the image to a PyTorch tensor
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalization
    ])
    
    # Apply transformations to the image
    image_tensor = transform(image).unsqueeze(0)  # Add batch dimension
    image_tensor = image_tensor.to(device)

    # Make sure the model is in evaluation mode
    model = model.to(device)
    model.eval()

    # Make predictions
    with torch.no_grad():
        output = model(image_tensor)
        _, predicted_class = torch.max(output, 1)
    
    # Get the predicted label
    predicted_label = label_dict[predicted_class.item()]
    true_label = os.path.basename(image_path).split(".")[0]

    # Plot the image and show prediction
    plt.imshow(image)
    plt.title(f"Predicted: {predicted_label}, True Label: {true_label}")
    plt.axis('off')  # Hide the axis
    plt.show()

# Example usage:
baseDir = os.getcwd()
uploadDir = os.path.join(baseDir, 'upload', 'snack')
# Detect if a GPU is available, otherwise use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for file in os.listdir(uploadDir): 
    image_path = os.path.join(uploadDir, file)  # Replace with the path to your image
    # Replace with the true label of the image
    classify_and_show_image(model, image_path, device)

# %%
def evaluate_model(model, data_loader):
    model.eval()
    total = 0
    correct = 0
    loss_total = 0
    all_targets = []
    all_preds = []
    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labelsx)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            loss_total += loss.item()
            all_targets.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
    val_loss = loss_total / len(data_loader)
    val_acc = 100 * correct / total
    val_f1 = f1_score(all_targets, all_preds, average='macro')
    return val_loss, val_acc, val_f1, all_preds, all_targets

# %%
# class_names = ['banana', 'blueberry', 'choco', 'cone', 'gum', 'octopus', 'shrimp']

# def plot_confusion_matrix(labels, predictions, class_names):
#     cm = confusion_matrix(labels, predictions)
#     plt.figure(figsize=(10, 7))
#     sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names)
#     plt.xlabel('Predicted')
#     plt.ylabel('True')
#     plt.show()

# _, _, _, preds, labels = evaluate_model(model, test_loader)
# plot_confusion_matrix(labels, preds, class_anmes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 11
#       8     plt.ylabel('True')
#       9     plt.show()
# ---> 11 _, _, _, preds, labels = evaluate_model(model, test_loader)
#      12 plot_confusion_matrix(labels, preds, class_anmes)
#
# Cell In[88], line 9, in evaluate_model(model, data_loader)
#       7 all_preds = []
#       8 with torch.no_grad():
# ----> 9     for inputs, labels in data_loader:
#      10         inputs, labels = inputs.to(device), labels.to(device)
#      11         outputs = model(inputs)
#
# ValueError: too many values to unpack (expected 2)
